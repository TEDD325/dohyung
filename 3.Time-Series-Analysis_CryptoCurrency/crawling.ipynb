# %%
import urllib.request as urq
import sys
from bs4 import BeautifulSoup
import csv
import copy
import os
import threading
import time
import datetime

# %%
user_dir_path = "/Users/dohk/GoogleDrive/coinCrawling/Bithumb_Data_Collector"
save_file_name = "coin_{0}.csv"
bithumb_graph_url = 'http://index.bithumb.com/api/bithumb/localAPI.php?api=graph&coin={0}&back={1}'
coin_list = ['BTC', 'ETH', 'XRP', 'BCH', 'LTC', 'EOS', 'DASH', 'XMR', 'ETC', 'QTUM', 'BTG', 'ZEC']

all_coin_msec_ago = dict() #얼마나 이전의 데이터를 가져올지
all_data_list = dict() #전체 데이터
for coin in coin_list:
    all_data_list[coin] = list()
    all_coin_msec_ago[coin] = 0
current_data_list = list() #현재 수집 데이터
long_msec_for_back_to = 3600000000 #1000시간
much_long_msec_for_back_to = 90000000 #25시간

loop_sleep_time = 3

# %%
def dataParser(coin, msec):
    if coin in coin_list:
        pass
    else:
        print('The coin({0}) you wrote is not on coin-list!!'.format(coin))
        return False
    try:
        html = urq.urlopen(bithumb_graph_url.format(coin, msec))
    except:
        print("URL_OPEN_ERROR")
        return False
    data = BeautifulSoup(html.read(), "html.parser")
    data_list = list()
    text_data = data.text
    text_data = text_data[text_data.find('[')+1:text_data.rfind(']')]
    l_index = 0
    r_index = 0
    append_l_flag = False
    append_r_flag = False
    for index, letter in enumerate(text_data):
        if letter == '[':
            l_index = index
            append_l_flag = True
        elif letter == ']':
            r_index = index
            append_r_flag = True
        if append_l_flag and append_r_flag:
            row = text_data[l_index+1:r_index].split(',')
            row.insert(1, datetime.datetime.fromtimestamp(int(int(row[0])/1000)).strftime('%Y-%m-%d %H:%M:%S'))
            data_list.append(row)
            append_l_flag = False
            append_r_flag = False
    return data_list

# %%
# Loop 1
def longBackTo(coin):
    print(coin + " - Loop 1 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin]))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 1 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
        print(coin + " - Loop 1 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
    print(coin + " - Loop 1 end")

# %%
# Loop 2
def muchLongBackTo(coin):
    print(coin + " - Loop 2 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin] + much_long_msec_for_back_to))
    if not current_data_list:
        print("Can't search much long ago data - {0}.".format(coin))
        print(coin + " - Loop 2 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
        print(coin + " - Loop 2 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
    print(coin + " - Loop 2 end")

# %%
# Loop 3
def currentOnly(coin):
    print(coin + " - Loop 3 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    current_data_list = dataParser(coin, str(0))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 3 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        print(coin + " - Loop 3 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
    print(coin + " - Loop 3 end")

# %%
# Loop 4
def saveAllDataList(coin):
    print(coin + " - Saving data start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    f = open(save_file_name.format(coin), 'w', encoding='utf-8', newline='')
    wr = csv.writer(f)
    for line in all_data_list[coin]:
        wr.writerow(line)
    f.close()
    print(coin + " - Saved data")

# %%
def openAllDataList(coin):
    global all_data_list
    f = open(save_file_name.format(coin), 'r', encoding='utf-8')
    rdr = csv.reader(f)
    for line in rdr:
        all_data_list[coin].append(line)
    f.close()

# %%
if __name__ == "__main__":
    timer = 0
    for coin in coin_list:
        if os.path.exists(user_dir_path + save_file_name.format(coin)):
            openAllDataList(coin)
    while True:
        for coin in coin_list:
            longBackTo(coin)
            if timer % 2 == 1:
                muchLongBackTo(coin)
                currentOnly(coin)
            saveAllDataList(coin)
        
        timer = timer + 1
# Out:
# BTC - Loop 1 start at 2018-03-19 12:23:41.144513
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 12:23:44.408431
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 12:23:47.427166
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 12:23:51.325977
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 12:23:54.348975
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 12:23:57.547532
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 12:24:00.565733
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 12:24:03.913231
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 12:24:06.931587
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 12:24:10.171588
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 12:24:13.190048
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 12:24:16.474942
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 12:24:19.493791
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 12:24:22.730803
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 12:24:25.747261
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 12:24:28.947287
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 12:24:31.971137
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 12:24:35.188673
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 12:24:38.205451
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 12:24:41.459092
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 12:24:44.480930
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 12:24:48.008621
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 12:24:51.027602
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 12:24:54.296630
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 12:24:57.318016
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 12:25:40.350203
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 12:26:20.546546
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 12:29:17.801874
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 12:29:20.849061
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 12:30:02.191828
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 12:30:49.601929
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 12:33:44.503739
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 12:33:47.545081
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 12:34:26.652094
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 12:35:05.952394
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 12:37:38.164228
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 12:37:41.207450
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 12:38:20.339036
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 12:39:01.441332
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 12:42:07.589592
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 12:42:10.636894
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 12:42:54.060648
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 12:43:36.501943
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 12:46:25.866123
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 12:46:28.901624
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 12:47:15.187384
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 12:47:21.517855
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 12:49:20.420777
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 12:49:23.451986
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 12:50:17.109555
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 12:51:04.954878
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 12:54:54.774811
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 12:54:57.838041
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 12:56:20.639705
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 12:57:36.644537
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 13:01:23.921877
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 13:01:26.967316
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 13:02:19.171748
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 13:03:09.485371
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 13:06:07.439311
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 13:06:10.478440
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 13:06:54.875861
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 13:07:44.682000
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 13:10:35.350929
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 13:10:38.407771
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 13:11:21.506639
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 13:11:44.413145
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 13:14:08.505399
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 13:14:11.542504
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 13:14:59.924495
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 13:15:45.257284
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 13:18:31.245400
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 13:18:34.286476
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 13:19:19.957139
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 13:19:23.010122
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 13:20:08.082418
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 13:20:11.126148
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 13:20:56.301916
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 13:20:59.338166
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 13:21:44.022724
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 13:21:47.066668
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 13:22:38.255881
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 13:22:41.292716
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 13:22:47.917286
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 13:22:50.943719
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 13:23:37.605471
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 13:23:40.646912
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 13:24:25.827675
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 13:24:28.876088
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 13:25:17.860717
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 13:25:20.901696
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 13:26:21.547100
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 13:26:24.603258
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 13:27:08.460403
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 13:27:11.516190
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 13:28:16.061170
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 13:28:19.128420
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 13:29:08.851566
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 13:30:19.192656
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 13:37:23.572811
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 13:37:26.642793
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 13:38:15.201044
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 13:39:04.729765
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 13:44:34.767577
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 13:44:37.876599
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 13:45:34.924077
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 13:46:31.668960
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 13:52:19.771454
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 13:52:22.835721
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 13:53:10.316997
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 13:53:59.634388
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 13:59:25.904569
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 13:59:28.983266
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 14:00:23.136330
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 14:01:14.711308
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 14:06:44.399680
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 14:06:47.478958
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 14:06:53.734332
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 14:06:56.853588
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 14:08:52.425215
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 14:08:55.459631
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 14:09:45.421590
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 14:10:39.616557
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 14:16:14.680293
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 14:16:17.753286
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 14:17:07.931711
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 14:17:38.905205
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 14:22:44.582562
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 14:22:47.652340
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 14:23:39.275287
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 14:24:29.360197
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 14:29:57.322016
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 14:30:00.398498
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 14:30:18.829285
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 14:30:21.952620
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 14:33:57.236460
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 14:34:00.288485
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 14:34:03.402609
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 14:34:06.526392
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 14:36:37.021339
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 14:36:40.059622
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 14:37:28.966380
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 14:37:34.819467
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 14:41:53.997459
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 14:41:57.061855
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 14:42:54.228011
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 14:42:57.311365
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 14:43:47.437017
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 14:43:50.510228
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 14:44:38.473409
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 14:44:41.547726
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 14:45:29.139255
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 14:45:32.209764
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 14:46:18.656144
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 14:46:21.715500
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 14:46:25.827340
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 14:46:28.862643
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 14:47:15.706394
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 14:47:18.771103
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 14:47:47.756990
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 14:47:50.822324
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 14:48:34.892472
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 14:48:37.956803
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 14:48:41.064495
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 14:48:44.117827
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 14:48:47.224090
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 14:48:50.255438
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 14:48:55.318626
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 14:48:58.371425
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 14:49:44.909032
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 14:50:34.321330
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 14:57:45.993844
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 14:57:49.101049
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 14:58:35.726057
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 14:59:18.957129
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 15:06:21.778573
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 15:06:24.875539
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 15:07:15.262525
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 15:07:50.260368
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 15:15:11.272026
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 15:15:14.348702
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 15:15:27.804828
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 15:15:30.912647
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 15:20:36.016652
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 15:20:39.091695
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 15:21:24.444532
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 15:22:06.844088
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 15:29:18.309489
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 15:29:21.419277
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 15:29:24.586273
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 15:29:28.665581
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 15:31:12.140936
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 15:31:15.173283
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 15:31:55.938004
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 15:32:36.103556
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 15:39:17.130813
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 15:39:20.221426
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 15:39:23.435987
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 15:39:26.522483
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 15:43:49.430374
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 15:43:52.496574
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 15:44:34.472836
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 15:45:17.385774
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 15:52:02.471603
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 15:52:05.565780
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 15:52:11.754801
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 15:52:14.884408
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 15:55:12.225178
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 15:55:15.277841
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 15:55:18.394719
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 15:55:22.503464
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 15:57:33.969977
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 15:57:37.008287
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 15:57:43.189951
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 15:57:46.276109
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 16:01:25.113815
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 16:01:28.165146
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 16:02:16.824575
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 16:02:19.924399
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 16:03:02.945547
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 16:03:06.041713
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 16:03:40.434004
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 16:03:43.520780
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 16:03:46.640888
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 16:03:49.716175
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 16:04:32.213611
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 16:04:35.300034
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 16:04:38.407650
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 16:04:41.438738
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 16:05:22.908805
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 16:05:25.996245
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 16:05:29.106044
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 16:05:32.168974
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 16:06:14.411742
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 16:06:17.499413
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 16:06:20.619684
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 16:06:23.669556
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 16:06:28.802401
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 16:06:31.839357
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 16:06:34.957774
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 16:06:38.016739
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 16:06:41.130688
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 16:06:44.249399
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 16:13:54.582860
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 16:13:57.683643
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 16:14:04.910877
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 16:14:08.027220
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 16:20:53.273918
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 16:20:56.362059
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 16:20:59.542836
# Can't search much long ago data - XRP.
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 16:21:02.644785
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 16:28:08.389996
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 16:28:11.470614
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 16:28:15.656928
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 16:28:18.780257
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 16:33:21.063346
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 16:33:24.131601
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 16:33:27.315291
# Can't search much long ago data - LTC.
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 16:33:30.406986
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 16:40:20.944385
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 16:40:24.027220
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 16:40:27.211742
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 16:40:30.331175
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 16:42:15.393750
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 16:42:18.424450
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 16:42:21.529820
# Can't search much long ago data - DASH.
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 16:42:24.805226
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 16:50:01.733491
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 16:50:04.872742
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 16:50:09.074354
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 16:50:12.178257
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 16:54:58.651295
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 16:55:01.710066
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 16:55:04.815400
# Can't search much long ago data - ETC.
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 16:55:07.973646
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 17:02:20.115118
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 17:02:23.202607
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 17:02:29.385602
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 17:02:32.490542
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 17:05:47.079872
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 17:05:50.124412
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 17:05:53.241383
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 17:05:56.333362
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 17:08:24.333299
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 17:08:27.369350
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 17:08:30.555861
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 17:08:33.670843
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 17:12:38.727458
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 17:12:41.778879
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 17:12:44.885329
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 17:12:47.974795
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 17:12:51.082376
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 17:12:54.169505
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 17:12:57.268126
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 17:13:00.340414
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 17:13:03.442262
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 17:13:06.516765
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 17:13:09.622790
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 17:13:12.726915
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 17:13:15.837079
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 17:13:18.867894
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 17:13:21.980525
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 17:13:25.066288
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 17:13:28.183744
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 17:13:31.244800
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 17:13:34.461420
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 17:13:37.549368
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 17:13:40.662252
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 17:13:43.711650
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 17:13:46.829601
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 17:13:49.865382
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 17:13:52.979436
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 17:13:56.028877
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 17:13:59.135344
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 17:14:02.244594
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 17:21:11.935141
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 17:21:15.034693
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 17:21:18.283211
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 17:21:21.380148
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 17:28:37.993054
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 17:28:41.080184
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 17:28:44.334439
# Can't search much long ago data - XRP.
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 17:28:47.433151
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 17:35:53.171740
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 17:35:56.260070
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 17:36:02.478428
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 17:36:05.563385
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 17:41:20.333220
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 17:41:23.403706
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 17:41:26.575323
# Can't search much long ago data - LTC.
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 17:41:29.699492
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 17:48:07.748347
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 17:48:10.836261
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 17:48:17.074623
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 17:48:20.164726
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 17:49:58.566642
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 17:50:01.598818
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 17:50:04.689246
# Can't search much long ago data - DASH.
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 17:50:07.764442
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 17:56:49.545358
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 17:56:52.632912
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 17:56:55.809694
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 17:56:58.922732
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 18:01:22.135687
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 18:01:25.202824
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 18:01:28.292343
# Can't search much long ago data - ETC.
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 18:01:31.346526
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 18:09:42.217501
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 18:09:45.321508
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 18:09:48.525235
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 18:09:51.627705
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 18:13:21.197917
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 18:13:24.253280
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 18:13:27.377536
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 18:13:30.498816
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 18:15:57.258654
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 18:16:00.295647
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 18:16:06.479141
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 18:16:09.578740
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 18:20:25.092542
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 18:20:28.153753
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 18:20:31.247990
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 18:20:34.360318
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 18:20:37.441991
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 18:20:40.549369
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 18:20:43.653226
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 18:20:46.751169
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 18:20:49.847265
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 18:20:52.929533
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 18:20:56.016508
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 18:20:59.111835
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 18:21:02.222580
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 18:21:05.262490
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 18:21:08.466699
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 18:21:11.560257
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 18:21:14.649828
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 18:21:17.713369
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 18:21:20.790360
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 18:21:23.893518
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 18:21:27.011723
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 18:21:30.071620
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 18:21:33.176515
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 18:21:36.219810
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 18:21:39.312507
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 18:21:42.388039
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 18:21:45.454517
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 18:21:48.574579
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 18:30:20.441603
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 18:30:23.555462
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 18:30:29.709708
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 18:30:32.800657
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 18:38:14.219011
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 18:38:17.329366
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 18:38:23.520543
# Can't search much long ago data - XRP.
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 18:38:26.631382
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 18:45:54.268307
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 18:45:57.362534
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 18:46:03.604046
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 18:46:06.685366
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 18:51:44.054575
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 18:51:47.133706
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 18:51:50.262834
# Can't search much long ago data - LTC.
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 18:51:53.350696
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 18:59:33.479539
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 18:59:36.587819
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 18:59:39.671042
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 18:59:42.698795
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 19:01:34.514126
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 19:01:37.550758
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 19:01:40.576427
# Can't search much long ago data - DASH.
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 19:01:43.598344
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 19:19:17.528327
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 19:19:20.613579
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 19:19:23.773049
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 19:19:26.818395
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 19:23:46.922525
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 19:23:49.980243
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 19:23:53.032996
# Can't search much long ago data - ETC.
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 19:23:56.139417
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 19:30:52.795008
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 19:30:55.877846
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 19:30:59.007886
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 19:31:02.114117
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 19:33:59.898815
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 19:34:02.949188
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 19:34:05.997288
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 19:34:09.126825
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 19:36:14.632911
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 19:36:17.667527
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 19:36:20.929290
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 19:36:24.453203
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 19:40:03.578838
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 19:40:06.629544
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 19:40:09.785980
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 19:40:12.894449
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 19:40:16.063562
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 19:40:19.151033
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 19:40:22.273269
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 19:40:25.353877
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 19:40:28.465251
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 19:40:31.543249
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 19:40:34.619960
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 19:40:37.708523
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 19:40:40.753612
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 19:40:43.789831
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 19:40:46.852948
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 19:40:49.942566
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 19:40:53.023573
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 19:40:56.091270
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 19:40:59.203118
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 19:41:02.292488
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 19:41:05.386473
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 19:41:08.436657
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 19:41:11.533273
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 19:41:14.566090
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 19:41:17.675341
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 19:41:20.732403
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 19:41:24.018107
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 19:41:27.089045
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 19:50:32.591163
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 19:50:35.684598
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 19:50:38.723496
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 19:50:41.794132
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 19:57:23.995567
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 19:57:27.092332
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 19:57:30.130641
# Can't search much long ago data - XRP.
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 19:57:33.154469
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 20:04:03.530664
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 20:04:06.608984
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 20:04:09.651871
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 20:04:12.678049
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 20:09:20.654947
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 20:09:23.731498
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 20:09:26.774298
# Can't search much long ago data - LTC.
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 20:09:29.841580
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 20:16:33.193975
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 20:16:36.278028
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 20:16:39.382360
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 20:16:42.403123
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 20:18:26.168495
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 20:18:29.204340
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 20:18:32.250320
# Can't search much long ago data - DASH.
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 20:18:35.273242
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 20:25:17.907485
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 20:25:20.995557
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 20:25:24.031477
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 20:25:27.065349
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 20:29:46.877095
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 20:29:49.942086
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 20:29:52.975312
# Can't search much long ago data - ETC.
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 20:29:56.031801
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 20:37:04.802491
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 20:37:07.889426
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 20:37:10.945924
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 20:37:13.981609
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 20:40:22.258018
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 20:40:25.302864
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 20:40:28.325264
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 20:40:31.351881
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 20:42:36.566971
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 20:42:39.603497
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 20:42:42.639953
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 20:42:45.659561
# ZEC - Loop 3 end
# ZEC - Saving data start at 2018-03-19 20:46:31.522652
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 20:46:34.573450
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 20:46:37.596615
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 20:46:40.688897
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 20:46:43.725318
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 20:46:46.844265
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 20:46:49.868820
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 20:46:52.943779
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 20:46:55.967519
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 20:46:59.037038
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 20:47:02.061127
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 20:47:05.157370
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 20:47:08.182475
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 20:47:11.212885
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 20:47:14.233722
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 20:47:17.316849
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 20:47:20.345201
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 20:47:23.415129
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 20:47:26.440430
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 20:47:29.548040
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 20:47:32.574665
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 20:47:35.626825
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 20:47:38.661992
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 20:47:41.706291
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 20:47:44.747463
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 20:47:47.812968
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 20:47:50.838466
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 20:47:53.861911
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 21:23:01.865600
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 21:23:04.986274
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 21:23:11.072318
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 21:23:14.096048
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-25-832689fa0b94> in <module>()
#       9             if timer % 2 == 1:
#      10                 muchLongBackTo(coin)
# ---> 11                 currentOnly(coin)
#      12             saveAllDataList(coin)
#      13
#
# <ipython-input-15-ed4e3f04dd52> in currentOnly(coin)
#      25                     if int(a_row[0]) == int(row[0]):
#      26                         break
# ---> 27                     elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
#      28                         all_data_list[coin].insert(i+1, row)
#      29                         break
#
# KeyboardInterrupt:
