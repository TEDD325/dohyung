# %%
import urllib.request as urq
import sys
from bs4 import BeautifulSoup
import csv
import copy
import os
import threading
import time
import datetime
/Users/dohk/GoogleDrive/github/deeplink/5.DoHyung/coin/coinData_2

# %%
user_dir_path = "/Users/dohk/GoogleDrive/github/deeplink/5.DoHyung/coin/coinData_2/Bithumb_Data_Collector/"
user_dir_path = "/Users/dohk/Downloads/"
save_file_name = "coin_{0}.csv"
bithumb_graph_url = 'http://index.bithumb.com/api/bithumb/localAPI.php?api=graph&coin={0}&back={1}'
coin_list = ['BTC', 'ETH', 'XRP', 'BCH', 'LTC', 'EOS', 'DASH', 'XMR', 'ETC', 'QTUM', 'BTG', 'ZEC']

all_coin_msec_ago = dict() #얼마나 이전의 데이터를 가져올지
all_data_list = dict() #전체 데이터
for coin in coin_list:
    all_data_list[coin] = list()
    all_coin_msec_ago[coin] = 0
current_data_list = list() #현재 수집 데이터
long_msec_for_back_to = 3600000000 #1000시간
much_long_msec_for_back_to = 90000000 #25시간

loop_sleep_time = 3

# %%
def dataParser(coin, msec):
    if coin in coin_list:
        pass
    else:
        print('The coin({0}) you wrote is not on coin-list!!'.format(coin))
        return False
    try:
        html = urq.urlopen(bithumb_graph_url.format(coin, msec))
    except:
        print("URL_OPEN_ERROR")
        return False
    data = BeautifulSoup(html.read(), "html.parser")
    data_list = list()
    text_data = data.text
    text_data = text_data[text_data.find('[')+1:text_data.rfind(']')]
    l_index = 0
    r_index = 0
    append_l_flag = False
    append_r_flag = False
    for index, letter in enumerate(text_data):
        if letter == '[':
            l_index = index
            append_l_flag = True
        elif letter == ']':
            r_index = index
            append_r_flag = True
        if append_l_flag and append_r_flag:
            row = text_data[l_index+1:r_index].split(',')
            row.insert(1, datetime.datetime.fromtimestamp(int(int(row[0])/1000)).strftime('%Y-%m-%d %H:%M:%S'))
            data_list.append(row)
            append_l_flag = False
            append_r_flag = False
    return data_list

# %%
# Loop 1
def longBackTo(coin):
    print(coin + " - Loop 1 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin]))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 1 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
        print(coin + " - Loop 1 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
    print(coin + " - Loop 1 end")

# %%
# Loop 2
def muchLongBackTo(coin):
    print(coin + " - Loop 2 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin] + much_long_msec_for_back_to))
    if not current_data_list:
        print("Can't search much long ago data - {0}.".format(coin))
        print(coin + " - Loop 2 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
        print(coin + " - Loop 2 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
    print(coin + " - Loop 2 end")

# %%
# Loop 3
def currentOnly(coin):
    print(coin + " - Loop 3 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    current_data_list = dataParser(coin, str(0))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 3 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        print(coin + " - Loop 3 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
    print(coin + " - Loop 3 end")

# %%
# Loop 4
def saveAllDataList(coin):
    print(coin + " - Saving data start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    f = open(save_file_name.format(coin), 'w', encoding='utf-8', newline='')
    wr = csv.writer(f)
    for line in all_data_list[coin]:
        wr.writerow(line)
    f.close()
    print(coin + " - Saved data")

# %%
def openAllDataList(coin):
    global all_data_list
    f = open(save_file_name.format(coin), 'r', encoding='utf-8')
    rdr = csv.reader(f)
    for line in rdr:
        all_data_list[coin].append(line)
    f.close()

# %%
if __name__ == "__main__":
    timer = 0
    for coin in coin_list:
        if os.path.exists(user_dir_path + save_file_name.format(coin)):
            openAllDataList(coin)
    while True:
        for coin in coin_list:
            longBackTo(coin)
            if timer % 2 == 1:
                muchLongBackTo(coin)
                currentOnly(coin)
            saveAllDataList(coin)
        
        timer = timer + 1
# Out:
# BTC - Loop 1 start at 2018-03-18 21:06:16.174007
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-18 21:06:22.501500
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-18 21:06:25.526026
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-18 21:06:28.721191
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-18 21:06:31.743070
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-18 21:06:34.907220
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-18 21:06:37.923029
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-18 21:06:41.103441
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-18 21:06:44.121586
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-18 21:06:47.308794
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-18 21:06:50.330542
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-18 21:06:53.504667
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-18 21:06:56.522755
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-18 21:06:59.707078
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-18 21:07:02.720995
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-18 21:07:05.898933
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-18 21:07:08.915221
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-18 21:07:12.104308
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-18 21:07:15.125367
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-18 21:07:18.301063
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-18 21:07:21.329278
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-18 21:07:24.501561
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-18 21:07:27.524276
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-18 21:07:30.692666
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-18 21:07:33.709380
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-18 21:08:13.091481
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-18 21:08:55.772406
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-18 21:11:47.749101
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-18 21:11:50.802681
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-18 21:12:36.396865
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-18 21:13:22.944632
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-18 21:16:10.878774
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-18 21:16:13.927040
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-18 21:16:56.912699
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-18 21:17:45.627017
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-18 21:20:33.226150
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-18 21:20:36.262274
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-18 21:21:17.321865
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-18 21:21:57.377892
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-18 21:24:41.338513
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-18 21:24:44.378825
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-18 21:25:25.570788
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-18 21:26:12.636936
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-18 21:28:56.585469
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-18 21:28:59.624057
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-18 21:29:41.646678
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-18 21:29:47.490805
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-18 21:31:34.501450
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-18 21:31:37.529294
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-18 21:32:17.268274
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-18 21:33:00.018776
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-18 21:35:41.649895
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-18 21:35:44.698387
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-18 21:36:27.524989
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-18 21:37:11.571871
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-18 21:39:44.911587
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-18 21:39:47.957118
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-18 21:40:25.668521
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-18 21:41:04.067199
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-18 21:43:33.900124
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 11:04:47.445712
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-19 11:04:50.546022
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 11:04:53.642330
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Saving data start at 2018-03-19 11:04:56.744730
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 11:04:59.829853
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Saving data start at 2018-03-19 11:05:02.947161
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 11:05:06.041550
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Saving data start at 2018-03-19 11:05:09.161736
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 11:05:12.233596
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Saving data start at 2018-03-19 11:05:15.339805
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 11:05:18.426876
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Saving data start at 2018-03-19 11:05:21.516693
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 11:05:24.543096
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Saving data start at 2018-03-19 11:05:27.655420
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 11:05:30.735474
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Saving data start at 2018-03-19 11:05:33.821946
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 11:05:36.883327
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Saving data start at 2018-03-19 11:05:39.999655
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 11:05:43.105765
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Saving data start at 2018-03-19 11:05:46.228766
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 11:05:49.273442
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Saving data start at 2018-03-19 11:05:52.429918
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 11:05:55.466018
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Saving data start at 2018-03-19 11:05:58.581477
# ZEC - Saved data
# BTC - Loop 1 start at 2018-03-19 11:06:01.632741
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-19 11:06:04.745128
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-19 11:06:07.849643
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-19 11:13:38.164655
# BTC - Saved data
# ETH - Loop 1 start at 2018-03-19 11:13:41.257852
# Can't search long ago data - ETH.
# ETH - Loop 1 end
# ETH - Loop 2 start at 2018-03-19 11:13:47.484488
# Can't search much long ago data - ETH.
# ETH - Loop 2 end
# ETH - Loop 3 start at 2018-03-19 11:13:50.596784
# ETH - Loop 3 end
# ETH - Saving data start at 2018-03-19 11:20:48.183080
# ETH - Saved data
# XRP - Loop 1 start at 2018-03-19 11:20:51.273461
# Can't search long ago data - XRP.
# XRP - Loop 1 end
# XRP - Loop 2 start at 2018-03-19 11:20:54.408348
# Can't search much long ago data - XRP.
# XRP - Loop 2 end
# XRP - Loop 3 start at 2018-03-19 11:20:57.488227
# XRP - Loop 3 end
# XRP - Saving data start at 2018-03-19 11:27:52.755986
# XRP - Saved data
# BCH - Loop 1 start at 2018-03-19 11:27:55.836438
# Can't search long ago data - BCH.
# BCH - Loop 1 end
# BCH - Loop 2 start at 2018-03-19 11:28:02.066376
# Can't search much long ago data - BCH.
# BCH - Loop 2 end
# BCH - Loop 3 start at 2018-03-19 11:28:05.132316
# BCH - Loop 3 end
# BCH - Saving data start at 2018-03-19 11:33:58.075518
# BCH - Saved data
# LTC - Loop 1 start at 2018-03-19 11:34:01.159374
# Can't search long ago data - LTC.
# LTC - Loop 1 end
# LTC - Loop 2 start at 2018-03-19 11:34:04.333818
# Can't search much long ago data - LTC.
# LTC - Loop 2 end
# LTC - Loop 3 start at 2018-03-19 11:34:07.386102
# LTC - Loop 3 end
# LTC - Saving data start at 2018-03-19 11:41:05.674751
# LTC - Saved data
# EOS - Loop 1 start at 2018-03-19 11:41:08.762054
# Can't search long ago data - EOS.
# EOS - Loop 1 end
# EOS - Loop 2 start at 2018-03-19 11:41:11.910132
# Can't search much long ago data - EOS.
# EOS - Loop 2 end
# EOS - Loop 3 start at 2018-03-19 11:41:14.968761
# EOS - Loop 3 end
# EOS - Saving data start at 2018-03-19 11:42:56.520069
# EOS - Saved data
# DASH - Loop 1 start at 2018-03-19 11:42:59.551874
# Can't search long ago data - DASH.
# DASH - Loop 1 end
# DASH - Loop 2 start at 2018-03-19 11:43:02.630092
# Can't search much long ago data - DASH.
# DASH - Loop 2 end
# DASH - Loop 3 start at 2018-03-19 11:43:05.739766
# DASH - Loop 3 end
# DASH - Saving data start at 2018-03-19 11:50:04.606240
# DASH - Saved data
# XMR - Loop 1 start at 2018-03-19 11:50:07.697334
# Can't search long ago data - XMR.
# XMR - Loop 1 end
# XMR - Loop 2 start at 2018-03-19 11:50:13.862343
# Can't search much long ago data - XMR.
# XMR - Loop 2 end
# XMR - Loop 3 start at 2018-03-19 11:50:16.936445
# XMR - Loop 3 end
# XMR - Saving data start at 2018-03-19 11:54:46.908082
# XMR - Saved data
# ETC - Loop 1 start at 2018-03-19 11:54:49.969813
# Can't search long ago data - ETC.
# ETC - Loop 1 end
# ETC - Loop 2 start at 2018-03-19 11:54:53.028166
# Can't search much long ago data - ETC.
# ETC - Loop 2 end
# ETC - Loop 3 start at 2018-03-19 11:54:56.062648
# ETC - Loop 3 end
# ETC - Saving data start at 2018-03-19 12:03:30.065433
# ETC - Saved data
# QTUM - Loop 1 start at 2018-03-19 12:03:33.177013
# Can't search long ago data - QTUM.
# QTUM - Loop 1 end
# QTUM - Loop 2 start at 2018-03-19 12:03:36.294110
# Can't search much long ago data - QTUM.
# QTUM - Loop 2 end
# QTUM - Loop 3 start at 2018-03-19 12:03:39.317897
# QTUM - Loop 3 end
# QTUM - Saving data start at 2018-03-19 12:07:23.935903
# QTUM - Saved data
# BTG - Loop 1 start at 2018-03-19 12:07:26.998269
# Can't search long ago data - BTG.
# BTG - Loop 1 end
# BTG - Loop 2 start at 2018-03-19 12:07:30.021447
# Can't search much long ago data - BTG.
# BTG - Loop 2 end
# BTG - Loop 3 start at 2018-03-19 12:07:33.050906
# BTG - Loop 3 end
# BTG - Saving data start at 2018-03-19 12:10:12.070573
# BTG - Saved data
# ZEC - Loop 1 start at 2018-03-19 12:10:15.113251
# Can't search long ago data - ZEC.
# ZEC - Loop 1 end
# ZEC - Loop 2 start at 2018-03-19 12:10:21.298847
# Can't search much long ago data - ZEC.
# ZEC - Loop 2 end
# ZEC - Loop 3 start at 2018-03-19 12:10:24.336920
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-832689fa0b94> in <module>()
#       9             if timer % 2 == 1:
#      10                 muchLongBackTo(coin)
# ---> 11                 currentOnly(coin)
#      12             saveAllDataList(coin)
#      13
#
# <ipython-input-6-ed4e3f04dd52> in currentOnly(coin)
#      25                     if int(a_row[0]) == int(row[0]):
#      26                         break
# ---> 27                     elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
#      28                         all_data_list[coin].insert(i+1, row)
#      29                         break
#
# KeyboardInterrupt:
