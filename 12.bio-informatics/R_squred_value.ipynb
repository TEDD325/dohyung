# %%
def plot_growth_curve(time, rpm_150, rpm_230, group, member, legend_1, legend_2, x_label, y_label):
    rpm_150_np = np.array(rpm_150)
    rpm_230_np = np.array(rpm_230)
    df1 = pd.DataFrame(rpm_150_np,
                   index=time,
                   columns=[legend_1])
    df2 = pd.DataFrame(rpm_230_np,
                   index=time,
                   columns=[legend_2])
    df_result = df1.join(df2)
    
    # 
    slope_1, y_intercept_1 = np.polyfit(time,rpm_150_np,1) # m*x + b, m과 b를 return함
    # print("np.polyfit(time,rpm_150_np,1): ", np.polyfit(time,rpm_150_np,1))
    # print("coef_1: ", coef_1)
    poly1d_fn_1 = np.poly1d([slope_1, y_intercept_1]) 
    
    
    slope_2, y_intercept_2 = np.polyfit(time,rpm_230_np,1)
    # print("np.polyfit(time,rpm_230_np,1): ", np.polyfit(time,rpm_230_np,1))
    poly1d_fn_2 = np.poly1d([slope_2, y_intercept_2])
    
    f1 = plt.figure(figsize=(12, 11))

    plt.plot(time, rpm_150,  color='black', marker='o',\
         linestyle=' ',  linewidth=2, markersize=12,  alpha=.5)
    plt.plot(time,rpm_150_np, 'ko', time, poly1d_fn_1(time), '-k')
    plt.plot(time, rpm_230,  color='black', marker='x',\
         linestyle=' ',  linewidth=2, markersize=12,  alpha=.5)
    plt.plot(time,rpm_230_np, 'ko', time, poly1d_fn_2(time), '-k')
    
    plt.title("Bradford Assay [group "+group+"]-"+member)
    plt.rc('font', size=20)
    plt.rc('xtick', labelsize=20)
    plt.rc('ytick', labelsize=20)
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, rpm_150)
#     print(R_squared_value_1)
    R_squared_value_2 = r2_score(y2, rpm_230)
    
    plt.text(3.5, 0.5, "(R squred value-1st: {:1.4f})".format(R_squared_value_1), fontsize=20)
    plt.text(4, 0.15, "(R squred value-2nd: {:1.4f})".format(R_squared_value_2), fontsize=20)

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True, lw = 2, ls = '--', c = '.85')
    plt.legend([legend_1, legend_2])
    plt.show()
    
    return slope_1, y_intercept_1, slope_2, y_intercept_2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.490, 0.512, 0.556, 0.598, 0.639]
    DATA_2 = [0.00000001, 0.015, 0.089, 0.104, 0.140]
    member = "KDH"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9895
# R squared value_2: 0.9467

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.486, 0.500, 0.540, 0.587, 0.634]
    DATA_2 = [0.00000001, 0.010, 0.051, 0.095, 0.136]
    member = "KAR"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9693
# R squared value_2: 0.9667

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.497, 0.520, 0.564, 0.610, 0.668]
    DATA_2 = [0.00000001, 0.026, 0.076, 0.098, 0.161]
    member = "KMJ"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9791
# R squared value_2: 0.9749

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.138, 0.030, 0.498, 0.020, 0.041]
    DATA_2 = [0.00000001, -0.164, 0.161, -0.129, -0.086]
    member = "KSH"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: -37.4856
# R squared value_2: -33.8832

# %% [markdown]
# # 2nd -200609

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.507, 0.544, 0.594, 0.658, 0.728]
    DATA_2 = [0.00000001, 0.031, 0.093, 0.146, 0.218]
    member = "KMJ"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9850
# R squared value_2: 0.9848

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.494, 0.545, 0.594, 0.645, 0.723]
    DATA_2 = [0.00000001, 0.053, 0.102, 0.145, 0.225]
    member = "KSH"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9899
# R squared value_2: 0.9877

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.516, 0.558, 0.602, 0.668, 0.749]
    DATA_2 = [0.00000001, 0.040, 0.051, 0.155, 0.238]
    member = "KAR"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9776
# R squared value_2: 0.9115

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import math

if __name__ == "__main__":    
    x_axis_scale = [0.0, 2.5, 5.0, 7.5, 10.0]
    
    DATA_1 = [0.513, 0.535, 0.591, 0.666, 0.720]
    DATA_2 = [0.00000001, 0.017, 0.070, 0.133, 0.187]
    member = "KDH"
    
    slope_1, y_intercept_1, slope_2, y_intercept_2 = plot_growth_curve(x_axis_scale, DATA_1, DATA_2, "2", member, "NaCl(μg/ml)", "0(μg/ml)", "BSA sample(μg/ml)", "O.D. (595nm)")
    
    y1 = np.array(slope_1)*x_axis_scale + np.array(y_intercept_1)
    y2 = np.array(slope_2)*x_axis_scale + np.array(y_intercept_2)
    
    R_squared_value_1 = r2_score(y1, DATA_1)
    R_squared_value_2 = r2_score(y2, DATA_2)
    print("R squared value_1: {:1.4f}".format(R_squared_value_1))
    print("R squared value_2: {:1.4f}".format(R_squared_value_2))
# Out:
# R squared value_1: 0.9729
# R squared value_2: 0.9705
