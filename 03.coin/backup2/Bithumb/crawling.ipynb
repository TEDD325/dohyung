# %%
import urllib.request as urq
import sys
from bs4 import BeautifulSoup
import csv
import copy
import os
import threading
import time
import datetime

# %%
user_dir_path = "/Users/dohk/GoogleDrive/Bithumb_Data_Collector/"
save_file_name = "coin_{0}.csv"
bithumb_graph_url = 'http://index.bithumb.com/api/bithumb/localAPI.php?api=graph&coin={0}&back={1}'
coin_list = ['BTC']

all_coin_msec_ago = dict() #얼마나 이전의 데이터를 가져올지
all_data_list = dict() #전체 데이터
for coin in coin_list:
    all_data_list[coin] = list()
    all_coin_msec_ago[coin] = 0
current_data_list = list() #현재 수집 데이터
long_msec_for_back_to = 3600000000 #1000시간
much_long_msec_for_back_to = 90000000 #25시간

loop_sleep_time = 3

# %%
def dataParser(coin, msec):
    if coin in coin_list:
        pass
    else:
        print('The coin({0}) you wrote is not on coin-list!!'.format(coin))
        return False
    try:
        html = urq.urlopen(bithumb_graph_url.format(coin, msec))
    except:
        print("URL_OPEN_ERROR")
        return False
    data = BeautifulSoup(html.read(), "html.parser")
    data_list = list()
    text_data = data.text
    text_data = text_data[text_data.find('[')+1:text_data.rfind(']')]
    l_index = 0
    r_index = 0
    append_l_flag = False
    append_r_flag = False
    for index, letter in enumerate(text_data):
        if letter == '[':
            l_index = index
            append_l_flag = True
        elif letter == ']':
            r_index = index
            append_r_flag = True
        if append_l_flag and append_r_flag:
            row = text_data[l_index+1:r_index].split(',')
            row.insert(1, datetime.datetime.fromtimestamp(int(int(row[0])/1000)).strftime('%Y-%m-%d %H:%M:%S'))
            data_list.append(row)
            append_l_flag = False
            append_r_flag = False
    return data_list

# %%
# Loop 1
def longBackTo(coin):
    print(coin + " - Loop 1 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin]))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 1 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
        print(coin + " - Loop 1 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + long_msec_for_back_to
    print(coin + " - Loop 1 end")

# %%
# Loop 2
def muchLongBackTo(coin):
    print(coin + " - Loop 2 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    global all_coin_msec_ago
    current_data_list = dataParser(coin, str(all_coin_msec_ago[coin] + much_long_msec_for_back_to))
    if not current_data_list:
        print("Can't search much long ago data - {0}.".format(coin))
        print(coin + " - Loop 2 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
        print(coin + " - Loop 2 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
        #더욱 더 이전의 데이터를 가져오기 위함
        all_coin_msec_ago[coin] = all_coin_msec_ago[coin] + much_long_msec_for_back_to
    print(coin + " - Loop 2 end")

# %%
# Loop 3
def currentOnly(coin):
    print(coin + " - Loop 3 start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    global current_data_list
    global all_data_list
    current_data_list = dataParser(coin, str(0))
    if not current_data_list:
        print("Can't search long ago data - {0}.".format(coin))
        print(coin + " - Loop 3 end")
        return False
    if len(all_data_list[coin]) == 0:
        all_data_list[coin] = current_data_list
        print(coin + " - Loop 3 end")
        return current_data_list
    else:
        #row[0] = 현재 수집된 데이터 한 줄의 시간
        for row in current_data_list:
            if int(all_data_list[coin][0][0]) > int(row[0]):
                all_data_list[coin].insert(0, row)
            elif int(all_data_list[coin][-1][0]) < int(row[0]):
                all_data_list[coin].append(row)
            else:
                for i, a_row in enumerate(all_data_list[coin][0:-1]):
                    if int(a_row[0]) == int(row[0]):
                        break
                    elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
                        all_data_list[coin].insert(i+1, row)
                        break
    print(coin + " - Loop 3 end")

# %%
# Loop 4
def saveAllDataList(coin):
    print(coin + " - Saving data start at " + str(datetime.datetime.now()))
    time.sleep(loop_sleep_time)
    f = open(save_file_name.format(coin), 'w', encoding='utf-8', newline='')
    wr = csv.writer(f)
    for line in all_data_list[coin]:
        wr.writerow(line)
    f.close()
    print(coin + " - Saved data")

# %%
def openAllDataList(coin):
    global all_data_list
    f = open(save_file_name.format(coin), 'r', encoding='utf-8')
    rdr = csv.reader(f)
    for line in rdr:
        all_data_list[coin].append(line)
    f.close()

# %%
if __name__ == "__main__":
    timer = 0
    for coin in coin_list:
        if os.path.exists(user_dir_path + save_file_name.format(coin)):
            openAllDataList(coin)
    while True:
        for coin in coin_list:
            longBackTo(coin)
            if timer % 2 == 1:
                muchLongBackTo(coin)
                currentOnly(coin)
            saveAllDataList(coin)
        
        timer = timer + 1
# Out:
# BTC - Loop 1 start at 2018-03-06 22:22:02.363294
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 22:22:41.189047
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:22:44.223479
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 22:23:29.573992
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 22:24:27.310964
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 22:29:04.555243
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:29:07.613556
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 22:29:49.733767
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:29:52.791591
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 22:30:34.770345
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 22:31:17.442190
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 22:37:24.474580
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:37:27.556738
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 22:38:11.069505
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:38:14.156899
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 22:38:58.023930
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 22:39:01.081408
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 22:46:09.926714
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:46:13.027900
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 22:46:16.658991
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:46:19.799613
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 22:46:22.827864
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 22:46:25.852034
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 22:53:44.108278
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:53:47.198783
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 22:53:50.371131
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 22:53:53.547330
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 22:53:56.572952
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 22:53:59.598262
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:01:21.625128
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:01:24.725102
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:01:27.799617
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:01:30.891488
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:01:33.937902
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:01:36.989102
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:08:56.520089
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:08:59.618008
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:09:02.806150
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:09:05.897297
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:09:08.933909
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:09:11.984473
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:16:22.264314
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:16:25.359580
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:16:28.596000
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:16:31.698335
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:16:34.748145
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:16:37.809319
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:29:12.902080
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:29:15.997494
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:29:19.043616
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:29:22.146085
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:29:25.164319
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:29:28.193264
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:37:13.752276
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:37:16.846011
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:37:20.036997
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:37:23.129301
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:37:26.150141
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:37:29.170327
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:45:09.624055
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:45:12.726226
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:45:15.947791
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:45:19.040455
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:45:22.063215
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:45:25.081635
# BTC - Loop 3 end
# BTC - Saving data start at 2018-03-06 23:52:38.002446
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:52:41.092538
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Saving data start at 2018-03-06 23:52:44.314746
# BTC - Saved data
# BTC - Loop 1 start at 2018-03-06 23:52:47.416742
# Can't search long ago data - BTC.
# BTC - Loop 1 end
# BTC - Loop 2 start at 2018-03-06 23:52:50.479443
# Can't search much long ago data - BTC.
# BTC - Loop 2 end
# BTC - Loop 3 start at 2018-03-06 23:52:53.525273
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-832689fa0b94> in <module>()
#       9             if timer % 2 == 1:
#      10                 muchLongBackTo(coin)
# ---> 11                 currentOnly(coin)
#      12             saveAllDataList(coin)
#      13
#
# <ipython-input-6-ed4e3f04dd52> in currentOnly(coin)
#      25                     if int(a_row[0]) == int(row[0]):
#      26                         break
# ---> 27                     elif int(a_row[0]) < int(row[0]) and int(all_data_list[coin][i+1][0]) > int(row[0]):
#      28                         all_data_list[coin].insert(i+1, row)
#      29                         break
#
# KeyboardInterrupt:
