# %%
import urllib.request
import json

# %%
import time
def crawlingFrom_P_B(coinType):
    transactionData_p = []
    transactionData_b = []
    checkData_p = ''
    checkUnit_p = ''
    checkprice_p = ''
    checkType_p = ''
    checkData_b = ''
    checkUnit_b = ''
    checkprice_b = ''
    checkType_b = ''
    
    url_p = 'https://poloniex.com/public?command=returnTradeHistory&currencyPair=BTC_'+coinType+'&limit=1'
    urlTicker_poloniex = urllib.request.urlopen(url_p)
    readTicker_poloniex = urlTicker_poloniex.read()
    t_poloniex = json.loads(readTicker_poloniex)
    checkData_p = t_poloniex[0]['date']
    checkUnit_p = t_poloniex[0]['amount']
    checkprice_p = t_poloniex[0]['rate']
    
    url_b = 'https://api.bithumb.com/public/recent_transactions/'+coinType+'?count=1'
    urlTicker_bithumb = urllib.request.urlopen(url_b)
    readTicker_bithumb = urlTicker_bithumb.read()
    t_bithumb = json.loads(readTicker_bithumb)
    checkData_b = t_bithumb['data'][0]['transaction_date']
    checkUnit_b = t_bithumb['data'][0]['units_traded']
    checkprice_b = t_bithumb['data'][0]['price']
    
    while(True):
        time.sleep(1)

        url_p = 'https://poloniex.com/public?command=returnTradeHistory&currencyPair=BTC_'+coinType+'&limit=1'
        urlTicker_poloniex = urllib.request.urlopen(url_p)
        readTicker_poloniex = urlTicker_poloniex.read()
        t_poloniex = json.loads(readTicker_poloniex)
        transactionData_p.append(t_poloniex)
        if (transactionData_p[len(transactionData_p)-1][0]['date'] != checkData_p
                or transactionData_p[len(transactionData_p)-1][0]['amount'] != checkUnit_p  
                or transactionData_p[len(transactionData_p)-1][0]['rate'] != checkprice_p
                or transactionData_p[len(transactionData_p)-1][0]['type'] != checkType_p):
            print("Poloneix--", t_poloniex, end="\n\n")
            checkData_p = t_poloniex[0]['date']
            checkUnit_p = t_poloniex[0]['amount']
            checkprice_p = t_poloniex[0]['rate']
            checkType_p = t_poloniex[0]['type']
            
        url_b = 'https://api.bithumb.com/public/recent_transactions/'+coinType+'?count=1'
        urlTicker_bithumb = urllib.request.urlopen(url_b)
        readTicker_bithumb = urlTicker_bithumb.read()
        t_bithumb = json.loads(readTicker_bithumb)
        transactionData_b.append(t_bithumb)
        if (transactionData_b[len(transactionData_b)-1]['data'][0]['transaction_date'] != checkData_b
                or transactionData_b[len(transactionData_b)-1]['data'][0]['units_traded'] != checkUnit_b
                or transactionData_b[len(transactionData_b)-1]['data'][0]['price'] != checkprice_b
                or transactionData_b[len(transactionData_b)-1]['data'][0]['type'] != checkType_b):
            print("Bithumb--", t_bithumb, end="\n\n")
            checkData_b = t_bithumb['data'][0]['transaction_date']
            checkUnit_b = t_bithumb['data'][0]['units_traded']
            checkprice_b = t_bithumb['data'][0]['price']
            checkType_b = t_bithumb['data'][0]['type']

# %%
coinType = ['ETH', 'DASH', 'LTC', 'ETC', 'XRP', 'BCH', 'XMR', 'ZEC']
crawlingFrom_P_B(coinType[0])
# Out:
# Poloneix-- [{'globalTradeID': 261995381, 'tradeID': 36386548, 'date': '2017-11-16 15:04:17', 'type': 'buy', 'rate': '0.04383529', 'amount': '3.07379185', 'total': '0.13474055'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:21', 'type': 'bid', 'units_traded': '2.8', 'price': '369500', 'total': '1034600'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:27', 'type': 'bid', 'units_traded': '1.0', 'price': '369450', 'total': '369450'}]}
#
# Poloneix-- [{'globalTradeID': 261995552, 'tradeID': 36386549, 'date': '2017-11-16 15:04:31', 'type': 'sell', 'rate': '0.04369850', 'amount': '0.00000045', 'total': '0.00000001'}]
#
# Poloneix-- [{'globalTradeID': 261995596, 'tradeID': 36386553, 'date': '2017-11-16 15:04:35', 'type': 'sell', 'rate': '0.04369857', 'amount': '0.20479299', 'total': '0.00894916'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:34', 'type': 'ask', 'units_traded': '6.0303', 'price': '367700', 'total': '2217341'}]}
#
# Poloneix-- [{'globalTradeID': 261995603, 'tradeID': 36386554, 'date': '2017-11-16 15:04:36', 'type': 'buy', 'rate': '0.04382929', 'amount': '0.12803285', 'total': '0.00561158'}]
#
# Poloneix-- [{'globalTradeID': 261995618, 'tradeID': 36386555, 'date': '2017-11-16 15:04:38', 'type': 'buy', 'rate': '0.04382929', 'amount': '0.01867748', 'total': '0.00081862'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:38', 'type': 'ask', 'units_traded': '0.1905', 'price': '367700', 'total': '70047'}]}
#
# Poloneix-- [{'globalTradeID': 261995668, 'tradeID': 36386556, 'date': '2017-11-16 15:04:44', 'type': 'sell', 'rate': '0.04370900', 'amount': '2.00000000', 'total': '0.08741800'}]
#
# Poloneix-- [{'globalTradeID': 261995733, 'tradeID': 36386557, 'date': '2017-11-16 15:04:54', 'type': 'sell', 'rate': '0.04371500', 'amount': '2.07769383', 'total': '0.09082638'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:53', 'type': 'ask', 'units_traded': '4.0505', 'price': '367650', 'total': '1489166'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:04:57', 'type': 'ask', 'units_traded': '18.9388', 'price': '367650', 'total': '6962850'}]}
#
# Poloneix-- [{'globalTradeID': 261995785, 'tradeID': 36386558, 'date': '2017-11-16 15:05:01', 'type': 'buy', 'rate': '0.04382400', 'amount': '0.00000002', 'total': '0.00000000'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:00', 'type': 'ask', 'units_traded': '0.4399', 'price': '367650', 'total': '161729'}]}
#
# Poloneix-- [{'globalTradeID': 261995798, 'tradeID': 36386560, 'date': '2017-11-16 15:05:03', 'type': 'buy', 'rate': '0.04382859', 'amount': '15.96453927', 'total': '0.69970324'}]
#
# Poloneix-- [{'globalTradeID': 261995839, 'tradeID': 36386561, 'date': '2017-11-16 15:05:07', 'type': 'buy', 'rate': '0.04382857', 'amount': '18.14271416', 'total': '0.79516921'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:06', 'type': 'ask', 'units_traded': '3.0', 'price': '367650', 'total': '1102950'}]}
#
# Poloneix-- [{'globalTradeID': 261995848, 'tradeID': 36386562, 'date': '2017-11-16 15:05:09', 'type': 'buy', 'rate': '0.04382857', 'amount': '30.04205888', 'total': '1.31670048'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:10', 'type': 'ask', 'units_traded': '10.881', 'price': '367000', 'total': '3993327'}]}
#
# Poloneix-- [{'globalTradeID': 261995867, 'tradeID': 36386568, 'date': '2017-11-16 15:05:11', 'type': 'sell', 'rate': '0.04371041', 'amount': '16.63668450', 'total': '0.72719630'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:14', 'type': 'bid', 'units_traded': '15.8872', 'price': '367450', 'total': '5837752'}]}
#
# Poloneix-- [{'globalTradeID': 261995969, 'tradeID': 36386570, 'date': '2017-11-16 15:05:21', 'type': 'buy', 'rate': '0.04382397', 'amount': '19.24589033', 'total': '0.84343132'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:20', 'type': 'ask', 'units_traded': '22.42', 'price': '367000', 'total': '8228140'}]}
#
# Poloneix-- [{'globalTradeID': 261996025, 'tradeID': 36386572, 'date': '2017-11-16 15:05:27', 'type': 'sell', 'rate': '0.04371051', 'amount': '0.02750103', 'total': '0.00120208'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:27', 'type': 'bid', 'units_traded': '0.0663', 'price': '367450', 'total': '24362'}]}
#
# Poloneix-- [{'globalTradeID': 261996048, 'tradeID': 36386573, 'date': '2017-11-16 15:05:29', 'type': 'sell', 'rate': '0.04371051', 'amount': '0.02750103', 'total': '0.00120208'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:30', 'type': 'bid', 'units_traded': '0.26955504', 'price': '367450', 'total': '99048'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:34', 'type': 'ask', 'units_traded': '5.1147', 'price': '367050', 'total': '1877351'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:38', 'type': 'ask', 'units_traded': '6.2208', 'price': '367100', 'total': '2283656'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:43', 'type': 'bid', 'units_traded': '0.00374407', 'price': '368850', 'total': '1381'}]}
#
# Poloneix-- [{'globalTradeID': 261996213, 'tradeID': 36386577, 'date': '2017-11-16 15:05:48', 'type': 'sell', 'rate': '0.04371330', 'amount': '0.00000045', 'total': '0.00000001'}]
#
# Poloneix-- [{'globalTradeID': 261996222, 'tradeID': 36386579, 'date': '2017-11-16 15:05:50', 'type': 'sell', 'rate': '0.04371330', 'amount': '0.00005719', 'total': '0.00000249'}]
#
# Poloneix-- [{'globalTradeID': 261996232, 'tradeID': 36386580, 'date': '2017-11-16 15:05:51', 'type': 'sell', 'rate': '0.04371333', 'amount': '0.00000045', 'total': '0.00000001'}]
#
# Poloneix-- [{'globalTradeID': 261996283, 'tradeID': 36386584, 'date': '2017-11-16 15:05:56', 'type': 'buy', 'rate': '0.04382300', 'amount': '10.61837601', 'total': '0.46532909'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:53', 'type': 'bid', 'units_traded': '0.16', 'price': '368750', 'total': '59000'}]}
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:05:59', 'type': 'ask', 'units_traded': '1.3958', 'price': '367750', 'total': '513305'}]}
#
# Poloneix-- [{'globalTradeID': 261996318, 'tradeID': 36386591, 'date': '2017-11-16 15:06:00', 'type': 'buy', 'rate': '0.04397930', 'amount': '6.55127197', 'total': '0.28812035'}]
#
# Poloneix-- [{'globalTradeID': 261996371, 'tradeID': 36386597, 'date': '2017-11-16 15:06:04', 'type': 'sell', 'rate': '0.04371406', 'amount': '22.13075092', 'total': '0.96742497'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:06:02', 'type': 'ask', 'units_traded': '0.5858', 'price': '367450', 'total': '215252'}]}
#
# Poloneix-- [{'globalTradeID': 261996384, 'tradeID': 36386598, 'date': '2017-11-16 15:06:07', 'type': 'buy', 'rate': '0.04371403', 'amount': '0.00344855', 'total': '0.00015075'}]
#
# Poloneix-- [{'globalTradeID': 261996416, 'tradeID': 36386602, 'date': '2017-11-16 15:06:10', 'type': 'sell', 'rate': '0.04371190', 'amount': '0.59499462', 'total': '0.02600834'}]
#
# Poloneix-- [{'globalTradeID': 261996429, 'tradeID': 36386604, 'date': '2017-11-16 15:06:12', 'type': 'buy', 'rate': '0.04371403', 'amount': '6.57929000', 'total': '0.28760728'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:06:11', 'type': 'bid', 'units_traded': '1.0025', 'price': '368550', 'total': '369471'}]}
#
# Poloneix-- [{'globalTradeID': 261996442, 'tradeID': 36386605, 'date': '2017-11-16 15:06:13', 'type': 'buy', 'rate': '0.04371403', 'amount': '1.52417843', 'total': '0.06662798'}]
#
# Poloneix-- [{'globalTradeID': 261996513, 'tradeID': 36386606, 'date': '2017-11-16 15:06:19', 'type': 'buy', 'rate': '0.04387300', 'amount': '13.39720326', 'total': '0.58777549'}]
#
# Bithumb-- {'status': '0000', 'data': [{'transaction_date': '2017-11-17 0:06:17', 'type': 'ask', 'units_traded': '0.4529', 'price': '367450', 'total': '166418'}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-af8f7fe39fd8> in <module>()
#       1 coinType = ['ETH', 'DASH', 'LTC', 'ETC', 'XRP', 'BCH', 'XMR', 'ZEC']
# ----> 2 crawlingFrom_P_B(coinType[0])
#
# <ipython-input-4-aa3742892017> in crawlingFrom_P_B(coinType)
#      32
#      33         url_p = 'https://poloniex.com/public?command=returnTradeHistory&currencyPair=BTC_'+coinType+'&limit=1'
# ---> 34         urlTicker_poloniex = urllib.request.urlopen(url_p)
#      35         readTicker_poloniex = urlTicker_poloniex.read()
#      36         t_poloniex = json.loads(readTicker_poloniex)
#
# ~/anaconda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~/anaconda/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~/anaconda/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/anaconda/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~/anaconda/lib/python3.6/http/client.py in connect(self)
#    1398
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#    1402                 try:
#
# ~/anaconda/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     399                          suppress_ragged_eofs=suppress_ragged_eofs,
#     400                          server_hostname=server_hostname,
# --> 401                          _context=self, _session=session)
#     402
#     403     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~/anaconda/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     806                         # non-blocking
#     807                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 808                     self.do_handshake()
#     809
#     810             except (OSError, ValueError):
#
# ~/anaconda/lib/python3.6/ssl.py in do_handshake(self, block)
#    1059             if timeout == 0.0 and block:
#    1060                 self.settimeout(None)
# -> 1061             self._sslobj.do_handshake()
#    1062         finally:
#    1063             self.settimeout(timeout)
#
# ~/anaconda/lib/python3.6/ssl.py in do_handshake(self)
#     681     def do_handshake(self):
#     682         """Start the SSL/TLS handshake."""
# --> 683         self._sslobj.do_handshake()
#     684         if self.context.check_hostname:
#     685             if not self.server_hostname:
#
# KeyboardInterrupt:
