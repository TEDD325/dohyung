# %% [markdown]
# Reference: https://www.kaggle.com/ash316/eda-to-prediction-dietanic/code

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('./dataset/_kaggle_01_titanic/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() #checking for total null values
# test set에도 null 데이터들이 존재함. 다른 양상
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,1,figsize=(18,8))
data['Survived'].value_counts().plot.pie(ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ed952bc5270d> in <module>()
#       1 f,ax=plt.subplots(1,1,figsize=(18,8))
# ----> 2 data['Survived'].value_counts().plot.pie(ax=ax[0])
#       3 ax[0].set_title('Survived')
#       4 ax[0].set_ylabel('')
#       5 plt.show()
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_8086815c_c4a3_11e8_8192_4a0003424620row0_col0 {
#             background-color:  #ffff66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row0_col1 {
#             background-color:  #cee666;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row1_col1 {
#             background-color:  #ffff66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row1_col2 {
#             background-color:  #ffff66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row2_col0 {
#             background-color:  #60b066;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row2_col1 {
#             background-color:  #dfef66;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row2_col2 {
#             background-color:  #90c866;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row3_col0 {
#             background-color:  #008066;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row3_col1 {
#             background-color:  #008066;
#         }    #T_8086815c_c4a3_11e8_8192_4a0003424620row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_8086815c_c4a3_11e8_8192_4a0003424620" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8086815c_c4a3_11e8_8192_4a0003424620level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row0_col0" class="data row0 col0" >80</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row0_col1" class="data row0 col1" >136</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_8086815c_c4a3_11e8_8192_4a0003424620level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row1_col0" class="data row1 col0" >97</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row1_col1" class="data row1 col1" >87</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_8086815c_c4a3_11e8_8192_4a0003424620level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row2_col0" class="data row2 col0" >372</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row2_col1" class="data row2 col1" >119</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_8086815c_c4a3_11e8_8192_4a0003424620level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row3_col0" class="data row3 col0" >549</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row3_col1" class="data row3 col1" >342</td>
#         <td id="T_8086815c_c4a3_11e8_8192_4a0003424620row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col0 {
#             background-color:  #ffff66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col1 {
#             background-color:  #ffff66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col2 {
#             background-color:  #f1f866;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col3 {
#             background-color:  #ffff66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col0 {
#             background-color:  #96cb66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col1 {
#             background-color:  #a3d166;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col2 {
#             background-color:  #f1f866;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col3 {
#             background-color:  #cfe766;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col0 {
#             background-color:  #a7d366;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col1 {
#             background-color:  #85c266;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col2 {
#             background-color:  #6eb666;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col3 {
#             background-color:  #85c266;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col0 {
#             background-color:  #cde666;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col1 {
#             background-color:  #f0f866;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col2 {
#             background-color:  #ffff66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col0 {
#             background-color:  #008066;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col1 {
#             background-color:  #008066;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col2 {
#             background-color:  #008066;
#         }    #T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col0" class="data row0 col0" >3</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col1" class="data row0 col1" >6</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col2" class="data row0 col2" >72</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col0" class="data row1 col0" >91</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col1" class="data row1 col1" >70</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col2" class="data row1 col2" >72</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col0" class="data row2 col0" >77</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col1" class="data row2 col1" >91</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col2" class="data row2 col2" >300</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col0" class="data row3 col0" >45</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col1" class="data row3 col1" >17</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col2" class="data row3 col2" >47</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col0" class="data row4 col0" >216</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col1" class="data row4 col1" >184</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col2" class="data row4 col2" >491</td>
#         <td id="T_faa92b9c_c4a3_11e8_a5c1_4a0003424620row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
data['Initial']
# Out:
# 0          Mr
# 1         Mrs
# 2        Miss
# 3         Mrs
# 4          Mr
# 5          Mr
# 6          Mr
# 7      Master
# 8         Mrs
# 9         Mrs
# 10       Miss
# 11       Miss
# 12         Mr
# 13         Mr
# 14       Miss
# 15        Mrs
# 16     Master
# 17         Mr
# 18        Mrs
# 19        Mrs
# 20         Mr
# 21         Mr
# 22       Miss
# 23         Mr
# 24       Miss
# 25        Mrs
# 26         Mr
# 27         Mr
# 28       Miss
# 29         Mr
#         ...
# 861        Mr
# 862       Mrs
# 863      Miss
# 864        Mr
# 865       Mrs
# 866      Miss
# 867        Mr
# 868        Mr
# 869    Master
# 870        Mr
# 871       Mrs
# 872        Mr
# 873        Mr
# 874       Mrs
# 875      Miss
# 876        Mr
# 877        Mr
# 878        Mr
# 879       Mrs
# 880       Mrs
# 881        Mr
# 882      Miss
# 883        Mr
# 884        Mr
# 885       Mrs
# 886       Rev
# 887      Miss
# 888      Miss
# 889        Mr
# 890        Mr
# Name: Initial, Length: 891, dtype: object

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col0 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col1 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col2 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col3 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col4 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col5 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col6 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col7 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col8 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col9 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col10 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col11 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col12 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col13 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col14 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col15 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col16 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col0 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col1 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col2 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col3 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col4 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col5 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col6 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col7 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col8 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col9 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col10 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col11 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col12 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col13 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col14 {
#             background-color:  #ffff66;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col15 {
#             background-color:  #008066;
#         }    #T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_62760d94_c4a4_11e8_9ffe_4a0003424620" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_62760d94_c4a4_11e8_9ffe_4a0003424620level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col0" class="data row0 col0" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col1" class="data row0 col1" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col2" class="data row0 col2" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col3" class="data row0 col3" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col4" class="data row0 col4" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col5" class="data row0 col5" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col6" class="data row0 col6" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col7" class="data row0 col7" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col8" class="data row0 col8" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col9" class="data row0 col9" >182</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col10" class="data row0 col10" >2</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col11" class="data row0 col11" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col12" class="data row0 col12" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col13" class="data row0 col13" >125</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col14" class="data row0 col14" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col15" class="data row0 col15" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_62760d94_c4a4_11e8_9ffe_4a0003424620level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col0" class="data row1 col0" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col1" class="data row1 col1" >2</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col2" class="data row1 col2" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col3" class="data row1 col3" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col4" class="data row1 col4" >6</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col5" class="data row1 col5" >1</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_col6" class="data row1 col6" >0</td>
#         <td id="T_62760d94_c4a4_11e8_9ffe_4a0003424620row1_c

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64
