# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## # version check

# %%
import matplotlib
print("matplotlib version: {}".format(matplotlib.__version__))
# Out:
# matplotlib version: 2.2.2

# %% [markdown]
# ### %matplotlib inline
#   - 브라우저에서 곧바로 이미지를 띄우기 위함

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### - plot( numpy.ndarray 1 , numpy.ndarray 2 , marker )
# - marker
#   - . , o v ^ < > 1 2 3 4 s p * h H + x D d | _

# %%
x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y, marker="_")
