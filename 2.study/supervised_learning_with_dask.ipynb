# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

from dask.distributed import Client
from dask_ml.model_selection import GridSearchCV

import time
import pandas as pd

import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.19.1.

# %%
cancer = load_breast_cancer()
print("Shape of cancer data: {}".format(cancer.data.shape))

print()

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)
print("Shape of train feature data: {}".format(X_train.shape))
print("Shape of train target data: {}".format(y_train.shape))
print("Shape of test feature data: {}".format(X_test.shape))
print("Shape of test target data: {}".format(y_test.shape))
# Out:
# Shape of cancer data: (569, 30)
#
# Shape of train feature data: (426, 30)
# Shape of train target data: (426,)
# Shape of test feature data: (143, 30)
# Shape of test target data: (143,)

# %%
pipe = Pipeline([
    ('scaler', MinMaxScaler()),
    ('poly', PolynomialFeatures()),
    ('gbr', GradientBoostingClassifier())
])

# %%
param_grid = {
    'poly__degree': [1, 2],
    'gbr__learning_rate': [0.01, 0.1, 1.0],
    'gbr__max_depth': [3, 4],
    'gbr__loss': ['deviance', 'exponential'],
    'gbr__max_features': ['auto', 'sqrt', 'log2'],
    'gbr__subsample': [0.9, 1.0],
    'gbr__n_estimators': [50]
}

# %%
c = Client('127.0.0.1:8786')

grid = GridSearchCV(pipe, param_grid=param_grid, cv=5, n_jobs=-1)

start_time = time.time()
grid.fit(X_train, y_train)
end_time = time.time()
print(end_time - start_time)

c.close()
# Out:
# 9.800934076309204

# %%
print("Best params:\n{}\n".format(grid.best_params_))
print("Best estimator:\n{}".format(grid.best_estimator_))
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
# Out:
# Best params:
# {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
#
# Best estimator:
# Pipeline(memory=None,
#      steps=[('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('poly', PolynomialFeatures(degree=1, include_bias=True, interaction_only=False)), ('gbr', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=1.0, loss='exponential', max_depth=4,
#              ...      presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False))])
# Best cross-validation score: 0.98

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_colwidth',200)

results = pd.DataFrame(grid.cv_results_)

#results2 = results[['rank_test_score', 'params', 'mean_test_score', 'std_test_score', 'mean_train_score', 'std_train_score']]
results2 = results[['rank_test_score', 'params', 'mean_test_score']]
results2 = results2.sort_values('rank_test_score')
display(results2)
# Out:
#      rank_test_score  \
# 142                1
# 140                2
# 129                2
# 79                 4
# 65                 5
# 89                 5
# 143                7
# 77                 7
# 55                 7
# 141                7
# 127                7
# 61                12
# 91                12
# 128               12
# 83                12
# 81                12
# 130               12
# 133               12
# 137               12
# 125               12
# 71                12
# 69                22
# 111               22
# 121               22
# 113               22
# 73                22
# 95                22
# 93                22
# 58                22
# 59                22
# ..               ...
# 18               115
# 6                115
# 100              115
# 46               115
# 48               115
# 35               115
# 116              115
# 42               122
# 10               122
# 98               122
# 4                125
# 62               125
# 20               125
# 12               125
# 28               125
# 8                125
# 24               125
# 60               125
# 34               133
# 0                133
# 86               133
# 30               136
# 96               136
# 36               136
# 44               136
# 32               140
# 2                140
# 14               142
# 26               143
# 38               144
#
#                                                                                                                                                                             params  \
# 142   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 140   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 129   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 79    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 65       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 89    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 143   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 77    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 55       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 141   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 127   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 61       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 91    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 128   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 83    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 81    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 130   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 133   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 137   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 125   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 71       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 69       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 111      {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 121   {'gbr__learning_rate': 1.0, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 113      {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 73    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 95    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 93    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 2}
# 58       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 59       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# ..                                                                                                                                                                             ...
# 18      {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 6       {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 100      {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 46   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 48       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 35   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 2}
# 116      {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 42   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 10      {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 98       {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 4       {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 62       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 20      {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 12      {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 28   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 8       {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 24   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 60       {'gbr__learning_rate': 0.1, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 34   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 0       {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 86    {'gbr__learning_rate': 0.1, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 30   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'sqrt', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 96       {'gbr__learning_rate': 1.0, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 36   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 44   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 32   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'log2', 'gbr__n_estimators': 50, 'gbr__subsample': 0.9, 'poly__degree': 1}
# 2       {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 14      {'gbr__learning_rate': 0.01, 'gbr__loss': 'deviance', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 26   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 3, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
# 38   {'gbr__learning_rate': 0.01, 'gbr__loss': 'exponential', 'gbr__max_depth': 4, 'gbr__max_features': 'auto', 'gbr__n_estimators': 50, 'gbr__subsample': 1.0, 'poly__degree': 1}
#
#      mean_test_score
# 142         0.978873
# 140         0.976526
# 129         0.976526
# 79          0.974178
# 65          0.971831
# 89          0.971831
# 143         0.969484
# 77          0.969484
# 55          0.969484
# 141         0.969484
# 127         0.969484
# 61          0.967136
# 91          0.967136
# 128         0.967136
# 83          0.967136
# 81          0.967136
# 130         0.967136
# 133         0.967136
# 137         0.967136
# 125         0.967136
# 71          0.967136
# 69          0.964789
# 111         0.964789
# 121         0.964789
# 113         0.964789
# 73          0.964789
# 95          0.964789
# 93          0.964789
# 58          0.964789
# 59          0.964789
# ..               ...
# 18          0.941315
# 6           0.941315
# 100         0.941315
# 46          0.941315
# 48          0.941315
# 35          0.941315
# 116         0.941315
# 42          0.938967
# 10          0.938967
# 98          0.938967
# 4           0.936620
# 62          0.936620
# 20          0.936620
# 12          0.936620
# 28          0.936620
# 8           0.936620
# 24          0.936620
# 60          0.936620
# 34          0.934272
# 0           0.934272
# 86          0.934272
# 30          0.931925
# 96          0.931925
# 36          0.931925
# 44          0.931925
# 32          0.927230
# 2           0.927230
# 14          0.924883
# 26          0.922535
# 38          0.917840
#
# [144 rows x 3 columns]

# %%
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Test-set score: 0.95

# %%
y_pred = grid.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.94      0.92      0.93        53
#           1       0.96      0.97      0.96        90
#
# avg / total       0.95      0.95      0.95       143
