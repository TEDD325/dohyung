# %%
from matplotlib import pylab
from pylab import *
import numpy as np
from datetime import datetime
from collections import deque
from keras.layers import Dense, Flatten, Conv2D, Input
from keras.optimizers import Adam, RMSprop
from keras.models import Sequential
# from environment_cnn_dqn_1 import Env as ENV_1
# from environment_cnn_dqn_2 import Env as ENV_2
import cartpole
import _pickle as pickle
import time
from keras import backend as K
import tensorflow as tf
import threading
from keras.models import Model
import os
# Out:
# Using TensorFlow backend.

# %%
SAVE_FOLDER_NAME = "./save"
GRAPTH_FOLDER_NAME = "./save/graph"
MODEL_FOLDER_NAME = "./save/model"
SAVED_ACTOR_MODEL_PATH = "./save/model/A3C_actor_rotary_pendulum.h5"
SAVED_CRITIC_MODEL_PATH = "./save/model/A3C_critic_rotary_pendulum.h5"
LOCAL_GRAPH_PATH = "./save/graph/A3C_rotary_pendulum_env_{0}.png"
LOSS_GRAPH_PATH_1 = "./save/graph/A3C_actor_loss_env_{0}.png"
LOSS_GRAPH_PATH_2 = "./save/graph/A3C_critic_loss_env_{0}.png"
LAST_EPISODE_N_PATH = "./save/A3C_last_episode_num.txt"
SAVED_REPLAY_MEMORY_PATH = "./save/A3C_memory.pickle"
GRAPH_DATA_PATH = "./save/A3C_graph_data.pickle"

EPISODES = 10000
HISTORY_LENGTH = 8
MEMORY_LENGTH = 2000
DISCOUNT_FACTOR = 0.99
LEARNING_RATE = 0.001
THREADS = 1
# ACTION_SIZE = 3
ACTION_SIZE = 2
STATE_SIZE = 4
ENV_COUNT = 0
TRAIN_ITERATION_N = 1000
BATCH_SIZE = 256
USE_IMITATION = False

if not os.path.exists(SAVE_FOLDER_NAME):
    os.makedirs(SAVE_FOLDER_NAME)

if not os.path.exists(GRAPTH_FOLDER_NAME):
    os.makedirs(GRAPTH_FOLDER_NAME)

if not os.path.exists(MODEL_FOLDER_NAME):
    os.makedirs(MODEL_FOLDER_NAME)

# %%
class A3C:
    def __init__(self, state_size, action_size):
        self.load_model = False
        self.state_size = state_size
        self.action_size = action_size
        self.replay_memory = deque(maxlen=MEMORY_LENGTH)
        self.hidden1, self.hidden2 = 24, 24
        self.actor, self.critic = self.build_model()
        self.sess = tf.InteractiveSession()
        K.set_session(self.sess)
        self.sess.run(tf.global_variables_initializer())
        self.actor_optimizer = self.actor_optimizer()
        self.critic_optimizer = self.critic_optimizer()
        

        if os.path.exists(SAVED_ACTOR_MODEL_PATH) and os.path.exists(SAVED_CRITIC_MODEL_PATH):
            self.load_model_from_saved_files()

    def build_model(self):
        state = Input(batch_shape=(None,  self.state_size))
        shared = Dense(self.hidden1, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_uniform')(state)

        actor_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='glorot_uniform')(shared)
        action_prob = Dense(self.action_size, activation='softmax', kernel_initializer='glorot_uniform')(actor_hidden)

        value_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='he_uniform')(shared)
        state_value = Dense(1, activation='linear', kernel_initializer='he_uniform')(value_hidden)

        actor = Model(inputs=state, outputs=action_prob)
        critic = Model(inputs=state, outputs=state_value)

        actor._make_predict_function()
        critic._make_predict_function()

        actor.summary()
        critic.summary()

        return actor, critic

    def actor_optimizer(self):
        action = K.placeholder(shape=[None, self.action_size])
        advantages = K.placeholder(shape=[None, ])
        policy = self.actor.output
        good_prob = K.sum(action * policy, axis=1)
        eligibility = K.log(good_prob + 1e-10) * K.stop_gradient(advantages)
        loss = -K.sum(eligibility)
        entropy = K.sum(policy * K.log(policy + 1e-10), axis=1)
        actor_loss = loss + 0.01 * entropy
        optimizer = Adam(lr=LEARNING_RATE)
        # optimizer = RMSprop(lr=LEARNING_RATE, rho=0.98, epsilon=0.001)

        updates = optimizer.get_updates(self.actor.trainable_weights, [], actor_loss)
        train = K.function([self.actor.input, action, advantages], [loss], updates=updates)

        return train

    def critic_optimizer(self):
        discounted_reward = K.placeholder(shape=(None,))
        value = self.critic.output
        loss = K.mean(K.square(discounted_reward - value))
        optimizer = Adam(lr=LEARNING_RATE)
        # optimizer = RMSprop(lr=LEARNING_RATE, rho=0.98, epsilon=0.001)

        updates = optimizer.get_updates(self.critic.trainable_weights, [], loss)
        train = K.function([self.critic.input, discounted_reward], [loss], updates=updates)

        return train

    def load_model_from_saved_files(self):
        self.actor.load_weights(SAVED_ACTOR_MODEL_PATH)
        self.critic.load_weights(SAVED_CRITIC_MODEL_PATH)
        self.replay_memory_load(SAVED_REPLAY_MEMORY_PATH)

    def replay_memory_dump(self, file_name):
        with open(file_name, 'wb') as memory_file:
            pickle.dump(self.replay_memory, memory_file)

    def replay_memory_load(self, file_name):
        with open(file_name, 'rb') as memory_file:
            self.replay_memory = pickle.load(memory_file)

    def append_sample(self, state, action, reward):
        self.replay_memory.append((state, action, reward))

    def train_model(self):
        agents = [
            Agent(
                self, self.action_size, self.state_size,
                [self.actor, self.critic], [self.actor_optimizer, self.critic_optimizer],
                DISCOUNT_FACTOR, self.replay_memory, self.sess, id
            ) for id in range(THREADS)
        ]

        for agent in agents:
            time.sleep(1)
            agent.start()

    def save_model(self, scores, episodes, agent_id):
        pylab.clf()
        pylab.figure(1)
        pylab.title("SCORE")
        pylab.plot(episodes, scores, 'g--')
        pylab.plot(episodes, self.exp_moving_average(scores, 10), 'r')
        pylab.savefig(LOCAL_GRAPH_PATH.format(agent_id))

        self.actor.save_weights(SAVED_ACTOR_MODEL_PATH)
        self.critic.save_weights(SAVED_CRITIC_MODEL_PATH)
        self.replay_memory_dump(SAVED_REPLAY_MEMORY_PATH)

    # select action based on epsilon greedy policy
    def get_action(self, state):
        policy = self.actor.predict(np.reshape(state, [1, self.state_size]))[0]
        return np.random.choice(self.action_size, 1, p=policy)[0]

    @staticmethod
    def exp_moving_average(values, window):
        if window >= len(values):
            sma = np.mean(np.asarray(values))
            a = [sma] * len(values)
        else:
            weights = np.exp(np.linspace(-1., 0., window))
            weights /= weights.sum()
            a = np.convolve(values, weights, mode="full")[:len(values)]
            a[:window] = a[window]
        return a

# %%
# make agents(local) and start training
class Agent(threading.Thread):
    def __init__(self, a3c, action_size, state_size, model, optimizer, discount_factor, memory, sess, id):
        threading.Thread.__init__(self)
        self.a3c = a3c
        self.action_size = action_size
        self.state_size = state_size
        self.actor, self.critic = model
        self.optimizer = optimizer
        self.discount_factor = discount_factor
        self.memory = memory
        self.avg_p_max = 0
        self.avg_loss = 0
        self.id = id
        self.sess = sess

    def replay_memory_dump(self, file_name):
        with open(file_name, 'wb') as memory_file:
            pickle.dump(self.memory, memory_file)

    def replay_memory_load(self, file_name):
        with open(file_name, 'rb') as memory_file:
            self.memory = pickle.load(memory_file)

    def append_sample(self, state, action, reward):
        self.memory.append((state, action, reward))

    # Thread interactive with environment
    def run(self):
        global ENV_COUNT
        # global env
        episode_start_num = 0
        env = None
        
        env = cartpole.CartPoleEnv()
#         if ENV_COUNT == 0:
#             env = ENV_1()
#             ENV_COUNT += 1

#         elif ENV_COUNT == 1:
#             env = ENV_2()

#         else:
#             print("[WARNING] THREAD")

        scores, episodes, actor_losses, critic_losses = [], [], [], []
        step = 0
        success_cnt = 0
        e = 0

        print("[INFO] env-", env)

        if os.path.exists(LAST_EPISODE_N_PATH):
            f = open(LAST_EPISODE_N_PATH, 'r')
            episode_start_num = int(f.readline())
            f.close()


        for episode in range(episode_start_num, EPISODES):
            done = False
            score = 0
            observe = env.reset()
#             state_for_manual_balance = observe
#             state = np.reshape(observe, [1, STATE_SIZE, 1, 1])
#             history = np.zeros([1, STATE_SIZE, HISTORY_LENGTH, 1])

#             for i in range(HISTORY_LENGTH):
#                 history = np.delete(history, 0, axis=2)
#                 history = np.append(history, state, axis=2)
#             history = np.reshape(history, [1, STATE_SIZE, HISTORY_LENGTH, 1])

            if len(self.memory) >= MEMORY_LENGTH - 1:
                e += 1

            while not done:
#                 print("ddd")
                step += 1
                previous_time = time.perf_counter()

                if USE_IMITATION:
                    # get action for the current history and go one step in environment
                    if len(self.memory) >= MEMORY_LENGTH - 1:
                        action= self.get_action(observe)
                    # imitation learning
                    else:
                        action = self.imitation(state_for_manual_balance, theta_n_k1, theta_dot_k1, alpha_n_k1, alpha_dot_k1)
                else:
                    action = self.get_action(observe)

                next_observe, reward, done, info = env.step(action)
                # pre-process the observation --> history
#                 prior_history = history

#                 state_for_manual_balance = next_observe
#                 next_state = [next_observe[0] * 100, next_observe[1], next_observe[2] * 100, next_observe[3]]
#                 next_state = np.reshape(next_state, (1, STATE_SIZE, 1, 1))
#                 history = np.delete(history, 0, axis=2)
#                 history = np.append(history, values=next_state, axis=2)
#                 history = np.reshape(history, [1, STATE_SIZE, HISTORY_LENGTH, 1])
                # save sample <s, a, r, s'> at replay memory
#                 if not (done and step == 1):
#                     self.append_sample(prior_history, action, reward)

                score += reward
                
                observe = next_observe

#                 self.avg_p_max += np.amax(self.actor.predict(np.float32(observe)))

                if not done:
                    while True:
                        current_time = time.perf_counter()
                        if current_time - previous_time >= 6 / 1000:
                            break
                else:
                    import random
#                     env.wait()


                    if len(self.memory) >= BATCH_SIZE and step > 5:
                        # Train model
                        for i in range(TRAIN_ITERATION_N):
                            mini_batch = (np.array(random.sample(self.memory, BATCH_SIZE)))[0][0]
                            actor_loss, critic_loss = self.train_model(score, action, mini_batch, done)
                            actor_losses.append(actor_loss)
                            critic_losses.append(critic_loss)

                    scores.append(score)
                    episodes.append(episode)

                    f = open(LAST_EPISODE_N_PATH, 'w')
                    f.write(str(episode) + "\n")
                    f.close()

                    self.a3c.save_model(scores, episodes, self.id)

                    print("id: {0}, episode:{1}  score:{2}  step:{3}  info:{4}  memory length:{5}".format(
                        self.id, episode, score, step, info, len(self.memory)
                    ))
                    # print("loss:", actor_losses, critic_losses)

                    step = 0
                    sys.stdout.flush()

                    # if serial successes are persisted, system will be shutted down.
                    if step >= 5000:
                        success_cnt += 1
                    else:
                        success_cnt = 0

                    if success_cnt >= 5:
                        env.close()
                        sys.exit()

    # In Policy Gradient, Q function is not available.
    # Instead agent uses sample returns for evaluating policy
#     def discount_rewards(self, rewards, history, done):
#         discounted_rewards = 0
#         if not done:
#             discounted_rewards = self.critic.predict(np.float32(history))
#         discounted_rewards = discounted_rewards * self.discount_factor + rewards
#         return discounted_rewards
    def discount_rewards(self, rewards, done=True):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        if not done:
            running_add = self.critic.predict(np.reshape(self.states[-1], (1, self.state_size)))[0]
        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards


    # update policy network and value network every episode
    def train_model(self, rewards, actions, history, done):
        discounted_rewards = self.discount_rewards(rewards, history, done)

        values = self.critic.predict(history)
        advantages = discounted_rewards - values[0]

        actor_loss = self.optimizer[0]([history, actions, advantages])
        critic_loss = self.optimizer[1]([history, discounted_rewards])

        return actor_loss, critic_loss

#     def get_action(self, history):
#         history = np.float32(history)
#         policy = self.actor.predict(history)[0]
#         policy = np.abs(policy) + [10e-10]
#         action_index = np.argmax(policy)
#         return action_index, policy

    def get_action(self, state):
        policy = self.actor.predict(np.reshape(state, [1, self.state_size]))[0]
        return np.random.choice(self.action_size, 1, p=policy)[0]
    
    def imitation(self, state_for_manual_balance, theta_n_k1, theta_dot_k1, alpha_n_k1, alpha_dot_k1):
        kp_theta = 2.0
        kd_theta = -2.0
        kp_alpha = -30.0
        kd_alpha = 2.5

        alpha = state_for_manual_balance[0]
        theta = state_for_manual_balance[2]

        theta_n = -theta
        theta_dot = (50.0 * theta_n) - (50.0 * theta_n_k1) + (0.7612 * theta_dot_k1)  # 5ms

        alpha_n = -alpha
        alpha_dot = (50.0 * alpha_n) - (50.0 * alpha_n_k1) + (0.7612 * alpha_dot_k1)  # 5ms

        # multiply by proportional and derivative gains
        motor_voltage = (theta * kp_theta) + (theta_dot * kd_theta) + (alpha * kp_alpha) + (
                alpha_dot * kd_alpha)

        # set the saturation limit to +/- 15V
        if motor_voltage > 15.0:
            motor_voltage = 15.0
        elif motor_voltage < -15.0:
            motor_voltage = -15.0

        # invert for positive CCW
        motor_voltage = -motor_voltage

        # convert the analog value to the PWM duty cycle that will produce the same average voltage
        motorPWM = motor_voltage * (625.0 / 15.0)
        motorPWM = int(motorPWM)
        motorPWM += -(motorPWM % 50)

        if motorPWM < 0:
            action = 0
        elif 0 < motorPWM:
            action = 2
        else:
            action = 1

        return action

# %%
if __name__ == "__main__":
    print(str(datetime.now()) + ' started!', flush=True)
    global_agent = A3C(action_size=ACTION_SIZE, state_size=STATE_SIZE)
    global_agent.train_model()
# Out:
# 2019-03-26 17:25:15.387344 started!
# WARNING:tensorflow:From /Users/dohyungkwon/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 745
# Trainable params: 745
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /Users/dohyungkwon/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# [INFO] env- <CartPoleEnv instance>
# id: 0, episode:0  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:1  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:2  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:3  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:4  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:5  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:6  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:7  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:8  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:9  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:10  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:11  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:12  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:13  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:14  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:15  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:16  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:17  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:18  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:19  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:20  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:21  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:22  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:23  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:24  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:25  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:26  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:27  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:28  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:29  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:30  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:31  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:32  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:33  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:34  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:35  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:36  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:37  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:38  score:54.0  step:54  info:{}  memory length:0
# id: 0, episode:39  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:40  score:61.0  step:61  info:{}  memory length:0
# id: 0, episode:41  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:42  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:43  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:44  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:45  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:46  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:47  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:48  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:49  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:50  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:51  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:52  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:53  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:54  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:55  score:39.0  step:39  info:{}  memory length:0
# id: 0, episode:56  score:39.0  step:39  info:{}  memory length:0
# id: 0, episode:57  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:58  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:59  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:60  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:61  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:62  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:63  score:62.0  step:62  info:{}  memory length:0
# id: 0, episode:64  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:65  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:66  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:67  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:68  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:69  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:70  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:71  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:72  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:73  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:74  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:75  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:76  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:77  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:78  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:79  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:80  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:81  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:82  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:83  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:84  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:85  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:86  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:87  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:88  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:89  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:90  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:91  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:92  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:93  score:82.0  step:82  info:{}  memory length:0
# id: 0, episode:94  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:95  score:50.0  step:50  info:{}  memory length:0
# id: 0, episode:96  score:47.0  step:47  info:{}  memory length:0
# id: 0, episode:97  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:98  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:99  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:100  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:101  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:102  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:103  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:104  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:105  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:106  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:107  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:108  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:109  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:110  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:111  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:112  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:113  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:114  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:115  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:116  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:117  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:118  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:119  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:120  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:121  score:60.0  step:60  info:{}  memory length:0
# id: 0, episode:122  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:123  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:124  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:125  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:126  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:127  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:128  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:129  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:130  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:131  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:132  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:133  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:134  score:41.0  step:41  info:{}  memory length:0
# id: 0, episode:135  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:136  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:137  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:138  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:139  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:140  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:141  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:142  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:143  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:144  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:145  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:146  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:147  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:148  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:149  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:150  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:151  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:152  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:153  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:154  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:155  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:156  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:157  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:158  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:159  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:160  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:161  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:162  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:163  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:164  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:165  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:166  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:167  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:168  score:58.0  step:58  info:{}  memory length:0
# id: 0, episode:169  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:170  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:171  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:172  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:173  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:174  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:175  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:176  score:61.0  step:61  info:{}  memory length:0
# id: 0, episode:177  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:178  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:179  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:180  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:181  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:182  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:183  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:184  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:185  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:186  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:187  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:188  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:189  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:190  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:191  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:192  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:193  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:194  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:195  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:196  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:197  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:198  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:199  score:46.0  step:46  info:{}  memory length:0
# id: 0, episode:200  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:201  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:202  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:203  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:204  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:205  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:206  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:207  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:208  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:209  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:210  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:211  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:212  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:213  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:214  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:215  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:216  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:217  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:218  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:219  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:220  score:43.0  step:43  info:{}  memory length:0
# id: 0, episode:221  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:222  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:223  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:224  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:225  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:226  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:227  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:228  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:229  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:230  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:231  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:232  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:233  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:234  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:235  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:236  score:54.0  step:54  info:{}  memory length:0
# id: 0, episode:237  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:238  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:239  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:240  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:241  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:242  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:243  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:244  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:245  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:246  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:247  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:248  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:249  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:250  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:251  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:252  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:253  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:254  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:255  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:256  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:257  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:258  score:43.0  step:43  info:{}  memory length:0
# id: 0, episode:259  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:260  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:261  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:262  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:263  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:264  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:265  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:266  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:267  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:268  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:269  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:270  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:271  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:272  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:273  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:274  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:275  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:276  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:277  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:278  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:279  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:280  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:281  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:282  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:283  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:284  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:285  score:68.0  step:68  info:{}  memory length:0
# id: 0, episode:286  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:287  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:288  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:289  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:290  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:291  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:292  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:293  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:294  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:295  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:296  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:297  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:298  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:299  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:300  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:301  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:302  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:303  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:304  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:305  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:306  score:46.0  step:46  info:{}  memory length:0
# id: 0, episode:307  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:308  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:309  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:310  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:311  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:312  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:313  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:314  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:315  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:316  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:317  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:318  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:319  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:320  score:54.0  step:54  info:{}  memory length:0
# id: 0, episode:321  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:322  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:323  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:324  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:325  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:326  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:327  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:328  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:329  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:330  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:331  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:332  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:333  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:334  score:119.0  step:119  info:{}  memory length:0
# id: 0, episode:335  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:336  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:337  score:44.0  step:44  info:{}  memory length:0
# id: 0, episode:338  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:339  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:340  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:341  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:342  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:343  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:344  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:345  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:346  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:347  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:348  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:349  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:350  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:351  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:352  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:353  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:354  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:355  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:356  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:357  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:358  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:359  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:360  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:361  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:362  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:363  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:364  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:365  score:46.0  step:46  info:{}  memory length:0
# id: 0, episode:366  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:367  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:368  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:369  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:370  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:371  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:372  score:55.0  step:55  info:{}  memory length:0
# id: 0, episode:373  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:374  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:375  score:51.0  step:51  info:{}  memory length:0
# id: 0, episode:376  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:377  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:378  score:53.0  step:53  info:{}  memory length:0
# id: 0, episode:379  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:380  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:381  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:382  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:383  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:384  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:385  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:386  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:387  score:46.0  step:46  info:{}  memory length:0
# id: 0, episode:388  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:389  score:44.0  step:44  info:{}  memory length:0
# id: 0, episode:390  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:391  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:392  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:393  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:394  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:395  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:396  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:397  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:398  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:399  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:400  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:401  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:402  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:403  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:404  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:405  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:406  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:407  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:408  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:409  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:410  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:411  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:412  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:413  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:414  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:415  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:416  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:417  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:418  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:419  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:420  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:421  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:422  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:423  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:424  score:47.0  step:47  info:{}  memory length:0
# id: 0, episode:425  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:426  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:427  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:428  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:429  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:430  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:431  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:432  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:433  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:434  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:435  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:436  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:437  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:438  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:439  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:440  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:441  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:442  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:443  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:444  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:445  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:446  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:447  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:448  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:449  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:450  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:451  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:452  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:453  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:454  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:455  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:456  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:457  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:458  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:459  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:460  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:461  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:462  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:463  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:464  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:465  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:466  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:467  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:468  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:469  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:470  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:471  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:472  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:473  score:53.0  step:53  info:{}  memory length:0
# id: 0, episode:474  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:475  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:476  score:63.0  step:63  info:{}  memory length:0
# id: 0, episode:477  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:478  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:479  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:480  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:481  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:482  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:483  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:484  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:485  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:486  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:487  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:488  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:489  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:490  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:491  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:492  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:493  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:494  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:495  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:496  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:497  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:498  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:499  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:500  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:501  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:502  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:503  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:504  score:56.0  step:56  info:{}  memory length:0
# id: 0, episode:505  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:506  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:507  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:508  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:509  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:510  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:511  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:512  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:513  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:514  score:71.0  step:71  info:{}  memory length:0
# id: 0, episode:515  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:516  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:517  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:518  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:519  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:520  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:521  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:522  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:523  score:79.0  step:79  info:{}  memory length:0
# id: 0, episode:524  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:525  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:526  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:527  score:43.0  step:43  info:{}  memory length:0
# id: 0, episode:528  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:529  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:530  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:531  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:532  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:533  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:534  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:535  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:536  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:537  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:538  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:539  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:540  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:541  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:542  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:543  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:544  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:545  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:546  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:547  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:548  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:549  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:550  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:551  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:552  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:553  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:554  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:555  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:556  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:557  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:558  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:559  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:560  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:561  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:562  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:563  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:564  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:565  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:566  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:567  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:568  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:569  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:570  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:571  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:572  score:54.0  step:54  info:{}  memory length:0
# id: 0, episode:573  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:574  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:575  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:576  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:577  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:578  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:579  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:580  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:581  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:582  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:583  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:584  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:585  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:586  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:587  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:588  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:589  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:590  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:591  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:592  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:593  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:594  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:595  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:596  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:597  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:598  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:599  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:600  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:601  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:602  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:603  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:604  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:605  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:606  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:607  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:608  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:609  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:610  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:611  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:612  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:613  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:614  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:615  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:616  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:617  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:618  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:619  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:620  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:621  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:622  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:623  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:624  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:625  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:626  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:627  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:628  score:39.0  step:39  info:{}  memory length:0
# id: 0, episode:629  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:630  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:631  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:632  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:633  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:634  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:635  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:636  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:637  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:638  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:639  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:640  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:641  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:642  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:643  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:644  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:645  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:646  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:647  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:648  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:649  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:650  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:651  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:652  score:81.0  step:81  info:{}  memory length:0
# id: 0, episode:653  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:654  score:43.0  step:43  info:{}  memory length:0
# id: 0, episode:655  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:656  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:657  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:658  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:659  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:660  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:661  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:662  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:663  score:49.0  step:49  info:{}  memory length:0
# id: 0, episode:664  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:665  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:666  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:667  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:668  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:669  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:670  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:671  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:672  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:673  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:674  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:675  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:676  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:677  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:678  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:679  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:680  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:681  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:682  score:46.0  step:46  info:{}  memory length:0
# id: 0, episode:683  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:684  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:685  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:686  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:687  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:688  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:689  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:690  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:691  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:692  score:21.0  step:21  info:{}  memory length:0
# ...
# id: 0, episode:1983  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:1984  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:1985  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:1986  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:1987  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:1988  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:1989  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:1990  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:1991  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:1992  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:1993  score:88.0  step:88  info:{}  memory length:0
# id: 0, episode:1994  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:1995  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:1996  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:1997  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:1998  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:1999  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2000  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2001  score:40.0  step:40  info:{}  memory length:0
# id: 0, episode:2002  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:2003  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:2004  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2005  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2006  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2007  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2008  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:2009  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2010  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2011  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2012  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2013  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2014  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2015  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2016  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2017  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2018  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:2019  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2020  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2021  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2022  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2023  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2024  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:2025  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2026  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2027  score:9.0  step:9  info:{}  memory length:0
# id: 0, episode:2028  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2029  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2030  score:34.0  step:34  info:{}  memory length:0
# id: 0, episode:2031  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2032  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2033  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2034  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2035  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2036  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2037  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2038  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2039  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2040  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2041  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:2042  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2043  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2044  score:32.0  step:32  info:{}  memory length:0
# id: 0, episode:2045  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:2046  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:2047  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2048  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2049  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2050  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:2051  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2052  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2053  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2054  score:37.0  step:37  info:{}  memory length:0
# id: 0, episode:2055  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2056  score:41.0  step:41  info:{}  memory length:0
# id: 0, episode:2057  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2058  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:2059  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2060  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:2061  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:2062  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:2063  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2064  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2065  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:2066  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2067  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2068  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2069  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2070  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2071  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:2072  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2073  score:62.0  step:62  info:{}  memory length:0
# id: 0, episode:2074  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:2075  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:2076  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2077  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:2078  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2079  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2080  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2081  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2082  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2083  score:106.0  step:106  info:{}  memory length:0
# id: 0, episode:2084  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2085  score:52.0  step:52  info:{}  memory length:0
# id: 0, episode:2086  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:2087  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2088  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2089  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:2090  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2091  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2092  score:48.0  step:48  info:{}  memory length:0
# id: 0, episode:2093  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2094  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2095  score:54.0  step:54  info:{}  memory length:0
# id: 0, episode:2096  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2097  score:51.0  step:51  info:{}  memory length:0
# id: 0, episode:2098  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2099  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2100  score:41.0  step:41  info:{}  memory length:0
# id: 0, episode:2101  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2102  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2103  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2104  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2105  score:33.0  step:33  info:{}  memory length:0
# id: 0, episode:2106  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2107  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2108  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:2109  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2110  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:2111  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:2112  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2113  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2114  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2115  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2116  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2117  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2118  score:51.0  step:51  info:{}  memory length:0
# id: 0, episode:2119  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2120  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:2121  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2122  score:59.0  step:59  info:{}  memory length:0
# id: 0, episode:2123  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2124  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2125  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2126  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2127  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2128  score:27.0  step:27  info:{}  memory length:0
# id: 0, episode:2129  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2130  score:23.0  step:23  info:{}  memory length:0
# id: 0, episode:2131  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2132  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2133  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:2134  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2135  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2136  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2137  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2138  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2139  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2140  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2141  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2142  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2143  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2144  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2145  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2146  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2147  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2148  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2149  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:2150  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2151  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2152  score:36.0  step:36  info:{}  memory length:0
# id: 0, episode:2153  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:2154  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:2155  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2156  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2157  score:25.0  step:25  info:{}  memory length:0
# id: 0, episode:2158  score:31.0  step:31  info:{}  memory length:0
# id: 0, episode:2159  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2160  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2161  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2162  score:66.0  step:66  info:{}  memory length:0
# id: 0, episode:2163  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2164  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2165  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2166  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:2167  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2168  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2169  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:2170  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2171  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2172  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2173  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2174  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2175  score:30.0  step:30  info:{}  memory length:0
# id: 0, episode:2176  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2177  score:38.0  step:38  info:{}  memory length:0
# id: 0, episode:2178  score:62.0  step:62  info:{}  memory length:0
# id: 0, episode:2179  score:45.0  step:45  info:{}  memory length:0
# id: 0, episode:2180  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2181  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2182  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:2183  score:24.0  step:24  info:{}  memory length:0
# id: 0, episode:2184  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2185  score:52.0  step:52  info:{}  memory length:0
# id: 0, episode:2186  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2187  score:8.0  step:8  info:{}  memory length:0
# id: 0, episode:2188  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:2189  score:39.0  step:39  info:{}  memory length:0
# id: 0, episode:2190  score:18.0  step:18  info:{}  memory length:0
# id: 0, episode:2191  score:55.0  step:55  info:{}  memory length:0
# id: 0, episode:2192  score:35.0  step:35  info:{}  memory length:0
# id: 0, episode:2193  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2194  score:16.0  step:16  info:{}  memory length:0
# id: 0, episode:2195  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2196  score:28.0  step:28  info:{}  memory length:0
# id: 0, episode:2197  score:22.0  step:22  info:{}  memory length:0
# id: 0, episode:2198  score:12.0  step:12  info:{}  memory length:0
# id: 0, episode:2199  score:42.0  step:42  info:{}  memory length:0
# id: 0, episode:2200  score:10.0  step:10  info:{}  memory length:0
# id: 0, episode:2201  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2202  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2203  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2204  score:26.0  step:26  info:{}  memory length:0
# id: 0, episode:2205  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2206  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2207  score:47.0  step:47  info:{}  memory length:0
# id: 0, episode:2208  score:15.0  step:15  info:{}  memory length:0
# id: 0, episode:2209  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2210  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2211  score:21.0  step:21  info:{}  memory length:0
# id: 0, episode:2212  score:29.0  step:29  info:{}  memory length:0
# id: 0, episode:2213  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2214  score:17.0  step:17  info:{}  memory length:0
# id: 0, episode:2215  score:11.0  step:11  info:{}  memory length:0
# id: 0, episode:2216  score:14.0  step:14  info:{}  memory length:0
# id: 0, episode:2217  score:13.0  step:13  info:{}  memory length:0
# id: 0, episode:2218  score:20.0  step:20  info:{}  memory length:0
# id: 0, episode:2219  score:19.0  step:19  info:{}  memory length:0
# id: 0, episode:2220  score:10.0  step:10  info:{}  memory length:0
