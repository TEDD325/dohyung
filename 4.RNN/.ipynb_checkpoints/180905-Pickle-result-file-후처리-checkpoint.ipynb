# %%
# import library
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import SimpleRNN, LSTM, GRU
from keras import layers, models
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from keras.utils import multi_gpu_model
from keras import metrics
from keras import losses
from keras import __version__
print('Using Keras version:', __version__, 'backend:', K.backend())
# assert(LV(__version__) >= LV("2.0.0"))
from keras.backend.tensorflow_backend import set_session
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# sess = tf.Session(config=config)
# set_session(sess)
# cfg = K.tf.ConfigProto()
# cfg.gpu_options.allow_growth = True
# K.set_session(K.tf.Session(config=cfg))

# import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# # The GPU id to use, usually either "0" or "1"
# os.environ["CUDA_VISIBLE_DEVICES"]="0" 

from sklearn.model_selection import GridSearchCV
# from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from sklearn.metrics import classification_report # https://stackoverflow.com/questions/50065484/getting-precision-recall-and-f1-score-per-class-in-keras

from IPython.display import Javascript
import numpy as np
from distutils.version import LooseVersion as LV
from datetime import datetime
import csv
import sys
from os import listdir
from os.path import isfile, join
import pprint
#import boto3
import pickle
import time
import os.path
import pickle
sys.path.append(os.getcwd())
from matplotlib import pyplot

import smtplib
from email.mime.text import MIMEText # simple MSG
from email.mime.multipart import MIMEMultipart # complex MSG
        
from link_aws_key import *
pp = pprint.PrettyPrinter(indent=4)

import warnings
warnings.filterwarnings("ignore")

coins = {
    0: 'KRW',
    1: 'BTC',
    2: 'ETH',
    3: 'XRP',
    4: 'BCH',
    5: 'LTC',
    6: 'DASH',
    7: 'ETC'
}

# aws_client = boto3.client(
#     's3',
#     aws_access_key_id=LINK_AWSAccessKeyId,
#     aws_secret_access_key=LINK_AWSSecretKey
# )

bucket = "bithumb10"
cleanup_file_name = "coin_{0}_{1}_cleanup.csv"
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Using Keras version: 2.2.2 backend: tensorflow
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
def Load_Dataset_X(dir_path, time_unit, window_size, gap, margin_rate):
    key_name_X = "X_" + \
                    str(time_unit) + "_" + \
                    str(window_size) + "_" + \
                    str(gap) + "_" + \
                    str(margin_rate)
                    

    with open(dir_path + key_name_X + ".pickle", 'rb') as handle:
        b_x = pickle.load(handle)
    return b_x
    
def Load_Dataset_y(dir_path, time_unit, window_size, gap, margin_rate):
    key_name_y = "y_" + \
                    str(time_unit) + "_" + \
                    str(window_size) + "_" + \
                    str(gap) + "_" + \
                    str(margin_rate)
                    

    with open(dir_path + key_name_y + ".pickle", 'rb') as handle:
        b_y = pickle.load(handle)
    return b_y

# %%
def save_to_Pickle_file(dir_path, dictionary):
    pickle_result_dir_path = "./evaluate_result/"
    new_file_name = str(dictionary.keys())[12:-3] + '_result.pickle'
    with open(pickle_result_dir_path + \
              new_file_name, 'wb') as handle:
        pickle.dump(dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# load pickle file 
def Load_result_pickle_file(dir_path, MODEL, coin, time_unit, window_size, gap, margin_rate):
    filename =  MODEL + "_" + \
                coin + "_" + \
                str(time_unit) + "_" + \
                str(window_size) + "_" + \
                str(gap) + "_" + \
                str(margin_rate) + "_" + \
                "result.pickle"

        
    b_x = pickle.load(open("./evaluate_result/"+filename, "rb"))

    # _key = str(b_x.keys())[12:-3]
    # b_x[_key].keys()
    b_x[str(b_x.keys())[12:-3]].keys()
    # 'MODEL'
    # 'grid_result.cv_results_['mean_test_score']'
    # 'grid_result.cv_results_['params']", 'grid_result.test_score']'

    dict_keys = tuple(b_x[str(b_x.keys())[12:-3]].keys())

    # key name 검사 및 수정
    if dict_keys[0] == 'MODEL: ':
        b_x[str(b_x.keys())[12:-3]]['MODEL'] = b_x[str(b_x.keys())[12:-3]]['MODEL: ']
        del b_x[str(b_x.keys())[12:-3]]['MODEL: ']
        b_x[str(b_x.keys())[12:-3]]['Cryptocurrency'] = b_x[str(b_x.keys())[12:-3]]['Cryptocurrency: ']
        del b_x[str(b_x.keys())[12:-3]]['Cryptocurrency: ']
        b_x[str(b_x.keys())[12:-3]]['Score'] = b_x[str(b_x.keys())[12:-3]]["grid_result.cv_results_['mean_test_score']"]
        del b_x[str(b_x.keys())[12:-3]]["grid_result.cv_results_['mean_test_score']"]
        b_x[str(b_x.keys())[12:-3]]['Params'] = b_x[str(b_x.keys())[12:-3]]["grid_result.cv_results_['params']"]
        del b_x[str(b_x.keys())[12:-3]]["grid_result.cv_results_['params']"]
        b_x[str(b_x.keys())[12:-3]]['test_score'] = b_x[str(b_x.keys())[12:-3]]['grid_result.test_score']
        del b_x[str(b_x.keys())[12:-3]]['grid_result.test_score']

#         pickle_result_dir_path = "./evaluate_result/"
#         save_to_Pickle_file(pickle_result_dir_path, b_x)
#         evaluate_result = pickle.load(open(dir_path + "SimpleRNN_BTC_10_10_1_0.1_result.pickle", "rb"))
    return b_x

# %%
# key = str(evaluate_result.keys())[12:-3]
# #evaluate_result[key]['Score']

# %%
dir_path = './evaluate_result/'
MODEL = "SimpleRNN"
coin = "BTC"
time_unit = 10
window_size = 10
gap = 1
margin_rate = 0.1
evaluate_result = Load_result_pickle_file(dir_path, MODEL, coin, time_unit, window_size, gap, margin_rate)

# %%
evaluate_result
# Out:
# {'SimpleRNN_BTC_10_10_1_0.1': {'MODEL': 'SimpleRNN',
#   'Cryptocurrency': 'BTC',
#   'Score': array([0.46582408, 0.53315288, 0.46275496, 0.53745817, 0.52997719,
#          0.40158571, 0.3999659 , 0.46720945, 0.46765703, 0.46863744,
#          0.53119205, 0.59832904, 0.53856647, 0.46096464, 0.46582408,
#          0.53784181, 0.39600162, 0.66983525, 0.60416889, 0.46279759,
#          0.53377097, 0.53745817, 0.48038108, 0.53745817, 0.46507811,
#          0.53728767, 0.46840299, 0.53711716, 0.53888617, 0.60325241,
#          0.53372834, 0.39521303, 0.59717812, 0.60436071, 0.46531256,
#          0.46821117, 0.41518361, 0.47213282, 0.33208295, 0.59867005,
#          0.4022038 , 0.53311025, 0.6617575 , 0.53764999, 0.46618641,
#          0.46271233, 0.33005819, 0.53777787, 0.40126601, 0.40103157,
#          0.52993457, 0.47183444, 0.46177455, 0.53803363, 0.46674055,
#          0.5985848 , 0.52840001, 0.53264136, 0.33005819, 0.46635691,
#          0.54131588, 0.40160702, 0.40245956, 0.53423986, 0.46684712,
#          0.46755046, 0.53138387, 0.46275496, 0.53389885, 0.46821117,
#          0.53423986, 0.46277627, 0.47654468, 0.39617213, 0.53600887,
#          0.39636395, 0.53705322, 0.40162834, 0.46301072, 0.53317419,
#          0.53095761, 0.53321682, 0.46620772, 0.53715979, 0.53470875,
#          0.59986359, 0.39943307, 0.60033249, 0.53423986, 0.60327373,
#          0.60429677, 0.53820414, 0.40005115, 0.53447431, 0.40086106,
#          0.46605853, 0.60257039, 0.32958929, 0.53200196, 0.53251348,
#          0.53786313, 0.53741555, 0.3996462 , 0.3297598 , 0.46844562,
#          0.32954667, 0.39598031, 0.46561095]),
#   'Params': [{'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': ['relu'],
#     'batch_size': [64],
#     'init': ['he_uniform'],
#     'n_state_units': [160],
#     'optimizer': ['adam'],
#     'window_size': [10]},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10}],
#   'test_score': 0.6607211353360898,
#   'train_score': 0.6698352480313772,
#   'Best_Params': {'activation': ['relu'],
#    'batch_size': [64],
#    'init': ['he_uniform'],
#    'n_state_units': [160],
#    'optimizer': ['adam'],
#    'window_size': [10]}}}

# %%
def Find_Best_Params(dictionary):
    key = str(dictionary.keys())[12:-3]
    Max_Score = max(dictionary[key]['Score'])
    for idx, item in enumerate(dictionary[key]['Score']):
        if item == Max_Score:
            Max_Score_Idx = idx
            Best_Params = dictionary[key]['Params'][idx]
            dictionary[key]['train_score'] = Max_Score
            dictionary[key]['Best_Params'] = Best_Params
            
            pickle_result_dir_path = "./evaluate_result/"
            save_to_Pickle_file(pickle_result_dir_path, dictionary)
        
            break
    
    
    return dictionary

# %%
# tmp = Find_Best_Params(evaluate_result)
# tmp

# %%
# evaluate_result = pickle.load(open("./evaluate_result/SimpleRNN_BTC_10_10_1_0.1_result.pickle", "rb"))
# evaluate_result

# %%
def Value_to_List(evaluate_result):
    for i in evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']:
    #     print(evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params'][i])
        if type(evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params'][i]) != list:
            evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params'][i] = \
                    [evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params'][i]]
    print(evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params'])
    
#     pickle_result_dir_path = "./evaluate_result/"
#     save_to_Pickle_file(pickle_result_dir_path, evaluate_result)

# %%
Value_to_List(evaluate_result)
# Out:
# {'activation': ['r'], 'batch_size': [64], 'init': ['he_uniform'], 'n_state_units': [160], 'optimizer': ['adam'], 'window_size': [10]}

# %%
evaluate_result = pickle.load(open("./evaluate_result/SimpleRNN_BTC_10_10_1_0.1_result.pickle", "rb"))
evaluate_result
# Out:
# {'SimpleRNN_BTC_10_10_1_0.1': {'MODEL': 'SimpleRNN',
#   'Cryptocurrency': 'BTC',
#   'Score': array([0.46582408, 0.53315288, 0.46275496, 0.53745817, 0.52997719,
#          0.40158571, 0.3999659 , 0.46720945, 0.46765703, 0.46863744,
#          0.53119205, 0.59832904, 0.53856647, 0.46096464, 0.46582408,
#          0.53784181, 0.39600162, 0.66983525, 0.60416889, 0.46279759,
#          0.53377097, 0.53745817, 0.48038108, 0.53745817, 0.46507811,
#          0.53728767, 0.46840299, 0.53711716, 0.53888617, 0.60325241,
#          0.53372834, 0.39521303, 0.59717812, 0.60436071, 0.46531256,
#          0.46821117, 0.41518361, 0.47213282, 0.33208295, 0.59867005,
#          0.4022038 , 0.53311025, 0.6617575 , 0.53764999, 0.46618641,
#          0.46271233, 0.33005819, 0.53777787, 0.40126601, 0.40103157,
#          0.52993457, 0.47183444, 0.46177455, 0.53803363, 0.46674055,
#          0.5985848 , 0.52840001, 0.53264136, 0.33005819, 0.46635691,
#          0.54131588, 0.40160702, 0.40245956, 0.53423986, 0.46684712,
#          0.46755046, 0.53138387, 0.46275496, 0.53389885, 0.46821117,
#          0.53423986, 0.46277627, 0.47654468, 0.39617213, 0.53600887,
#          0.39636395, 0.53705322, 0.40162834, 0.46301072, 0.53317419,
#          0.53095761, 0.53321682, 0.46620772, 0.53715979, 0.53470875,
#          0.59986359, 0.39943307, 0.60033249, 0.53423986, 0.60327373,
#          0.60429677, 0.53820414, 0.40005115, 0.53447431, 0.40086106,
#          0.46605853, 0.60257039, 0.32958929, 0.53200196, 0.53251348,
#          0.53786313, 0.53741555, 0.3996462 , 0.3297598 , 0.46844562,
#          0.32954667, 0.39598031, 0.46561095]),
#   'Params': [{'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': [[['relu']]],
#     'batch_size': [[[64]]],
#     'init': [[['he_uniform']]],
#     'n_state_units': [[[160]]],
#     'optimizer': [[['adam']]],
#     'window_size': [[[10]]]},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10}],
#   'test_score': 0.6607211353360898,
#   'train_score': 0.6698352480313772,
#   'Best_Params': {'activation': [[['relu']]],
#    'batch_size': [[[64]]],
#    'init': [[['he_uniform']]],
#    'n_state_units': [[[160]]],
#    'optimizer': [[['adam']]],
#    'window_size': [[[10]]]}}}

# %%
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['activation'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['activation'][0][0]
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['batch_size'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['batch_size'][0][0]
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['init'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['init'][0][0]
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['n_state_units'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['n_state_units'][0][0]
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['optimizer'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['optimizer'][0][0]
evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['window_size'] = \
        evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['window_size'][0][0]
# Out:
# --------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-28-7a3924fef722> in <module>()
#       1 evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['activation'] =         evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['activation'][0][0]
# ----> 2 evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['batch_size'] =         evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['batch_size'][0][0]
#       3 evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['init'] =         evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['init'][0][0]
#       4 evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['n_state_units'] =         evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['n_state_units'][0][0]
#       5 evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['optimizer'] =         evaluate_result[str(evaluate_result.keys())[12:-3]]['Best_Params']['optimizer'][0][0]
#
# TypeError: 'int' object is not subscriptable

# %%
evaluate_result
# Out:
# {'SimpleRNN_BTC_10_10_1_0.1': {'MODEL': 'SimpleRNN',
#   'Cryptocurrency': 'BTC',
#   'Score': array([0.46582408, 0.53315288, 0.46275496, 0.53745817, 0.52997719,
#          0.40158571, 0.3999659 , 0.46720945, 0.46765703, 0.46863744,
#          0.53119205, 0.59832904, 0.53856647, 0.46096464, 0.46582408,
#          0.53784181, 0.39600162, 0.66983525, 0.60416889, 0.46279759,
#          0.53377097, 0.53745817, 0.48038108, 0.53745817, 0.46507811,
#          0.53728767, 0.46840299, 0.53711716, 0.53888617, 0.60325241,
#          0.53372834, 0.39521303, 0.59717812, 0.60436071, 0.46531256,
#          0.46821117, 0.41518361, 0.47213282, 0.33208295, 0.59867005,
#          0.4022038 , 0.53311025, 0.6617575 , 0.53764999, 0.46618641,
#          0.46271233, 0.33005819, 0.53777787, 0.40126601, 0.40103157,
#          0.52993457, 0.47183444, 0.46177455, 0.53803363, 0.46674055,
#          0.5985848 , 0.52840001, 0.53264136, 0.33005819, 0.46635691,
#          0.54131588, 0.40160702, 0.40245956, 0.53423986, 0.46684712,
#          0.46755046, 0.53138387, 0.46275496, 0.53389885, 0.46821117,
#          0.53423986, 0.46277627, 0.47654468, 0.39617213, 0.53600887,
#          0.39636395, 0.53705322, 0.40162834, 0.46301072, 0.53317419,
#          0.53095761, 0.53321682, 0.46620772, 0.53715979, 0.53470875,
#          0.59986359, 0.39943307, 0.60033249, 0.53423986, 0.60327373,
#          0.60429677, 0.53820414, 0.40005115, 0.53447431, 0.40086106,
#          0.46605853, 0.60257039, 0.32958929, 0.53200196, 0.53251348,
#          0.53786313, 0.53741555, 0.3996462 , 0.3297598 , 0.46844562,
#          0.32954667, 0.39598031, 0.46561095]),
#   'Params': [{'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': ['relu'],
#     'batch_size': [64],
#     'init': ['he_uniform'],
#     'n_state_units': [160],
#     'optimizer': ['adam'],
#     'window_size': [10]},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10}],
#   'test_score': 0.6607211353360898,
#   'train_score': 0.6698352480313772,
#   'Best_Params': {'activation': ['relu'],
#    'batch_size': [64],
#    'init': ['he_uniform'],
#    'n_state_units': [160],
#    'optimizer': ['adam'],
#    'window_size': [10]}}}

# %%
pickle_result_dir_path = "./evaluate_result/"
save_to_Pickle_file(pickle_result_dir_path, evaluate_result)

# %%
evaluate_result = pickle.load(open("./evaluate_result/SimpleRNN_BTC_10_10_1_0.1_result.pickle", "rb"))
evaluate_result
# Out:
# {'SimpleRNN_BTC_10_10_1_0.1': {'MODEL': 'SimpleRNN',
#   'Cryptocurrency': 'BTC',
#   'Score': array([0.46582408, 0.53315288, 0.46275496, 0.53745817, 0.52997719,
#          0.40158571, 0.3999659 , 0.46720945, 0.46765703, 0.46863744,
#          0.53119205, 0.59832904, 0.53856647, 0.46096464, 0.46582408,
#          0.53784181, 0.39600162, 0.66983525, 0.60416889, 0.46279759,
#          0.53377097, 0.53745817, 0.48038108, 0.53745817, 0.46507811,
#          0.53728767, 0.46840299, 0.53711716, 0.53888617, 0.60325241,
#          0.53372834, 0.39521303, 0.59717812, 0.60436071, 0.46531256,
#          0.46821117, 0.41518361, 0.47213282, 0.33208295, 0.59867005,
#          0.4022038 , 0.53311025, 0.6617575 , 0.53764999, 0.46618641,
#          0.46271233, 0.33005819, 0.53777787, 0.40126601, 0.40103157,
#          0.52993457, 0.47183444, 0.46177455, 0.53803363, 0.46674055,
#          0.5985848 , 0.52840001, 0.53264136, 0.33005819, 0.46635691,
#          0.54131588, 0.40160702, 0.40245956, 0.53423986, 0.46684712,
#          0.46755046, 0.53138387, 0.46275496, 0.53389885, 0.46821117,
#          0.53423986, 0.46277627, 0.47654468, 0.39617213, 0.53600887,
#          0.39636395, 0.53705322, 0.40162834, 0.46301072, 0.53317419,
#          0.53095761, 0.53321682, 0.46620772, 0.53715979, 0.53470875,
#          0.59986359, 0.39943307, 0.60033249, 0.53423986, 0.60327373,
#          0.60429677, 0.53820414, 0.40005115, 0.53447431, 0.40086106,
#          0.46605853, 0.60257039, 0.32958929, 0.53200196, 0.53251348,
#          0.53786313, 0.53741555, 0.3996462 , 0.3297598 , 0.46844562,
#          0.32954667, 0.39598031, 0.46561095]),
#   'Params': [{'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': ['relu'],
#     'batch_size': [64],
#     'init': ['he_uniform'],
#     'n_state_units': [160],
#     'optimizer': ['adam'],
#     'window_size': [10]},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'relu',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 64,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 128,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'glorot_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 40,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 80,
#     'optimizer': 'adam',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'rmsprop',
#     'window_size': 10},
#    {'activation': 'softmax',
#     'batch_size': 256,
#     'init': 'he_uniform',
#     'n_state_units': 160,
#     'optimizer': 'adam',
#     'window_size': 10}],
#   'test_score': 0.6607211353360898,
#   'train_score': 0.6698352480313772,
#   'Best_Params': {'activation': ['relu'],
#    'batch_size': [64],
#    'init': ['he_uniform'],
#    'n_state_units': [160],
#    'optimizer': ['adam'],
#    'window_size': [10]}}}
